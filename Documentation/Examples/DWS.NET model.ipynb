// %%
#r "nuget: Jinaga.UnitTest"
#r "nuget: Jinaga.Graphviz"
using Jinaga;
using Jinaga.UnitTest;
using Jinaga.Graphviz;

var j = JinagaTest.Create();
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga.Graphviz, 0.1.1</span></li><li><span>Jinaga.UnitTest, 0.1.1</span></li></ul></div></div>

// %%
[FactType("DWS.Supplier")]
record Supplier(string publicKey);

[FactType("DWS.User")]
record User(string publicKey);

[FactType("DWS.Worker")]
record Worker(User user, Supplier Supplier);

[FactType("DWS.Dispatcher")]
record Dispatcher(User user, Supplier Supplier);

[FactType("DWS.Worker.Month")]
record WorkerMonth( Worker worker, int year, int month);

[FactType("DWS.Supplier.Month")]
record SupplierMonth( Supplier supplier, int year, int month);

[FactType("DWS.Task")]
record Task( SupplierMonth supplierMonth, User createdByUser, DateTime created);

[FactType("DWS.Task.Assignment")]
record TaskAssignment( Task task, WorkerMonth assignedToWorkerMonth, User assignedBy);

// %%
Jinaga.Graphviz.Renderer.RenderTypes(typeof(TaskAssignment))
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 2.49.1 (20210923.0004)
//  -->
// <!-- Pages: 1 -->
// <svg width="526pt" height="305pt"
//  viewBox="0.00 0.00 526.18 305.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 301)">
// <polygon fill="white" stroke="transparent" points="-4,4 -4,-301 522.18,-301 522.18,4 -4,4"/>
// <!-- DWS.Task.Assignment -->
// <g id="node1" class="node">
// <title>DWS.Task.Assignment</title>
// <ellipse fill="none" stroke="black" cx="96.84" cy="-18" rx="96.68" ry="18"/>
// <text text-anchor="middle" x="96.84" y="-14.3" font-family="Times New Roman,serif" font-size="14.00">DWS.Task.Assignment</text>
// </g>
// <!-- DWS.Task -->
// <g id="node2" class="node">
// <title>DWS.Task</title>
// <ellipse fill="none" stroke="black" cx="96.84" cy="-105" rx="51.99" ry="18"/>
// <text text-anchor="middle" x="96.84" y="-101.3" font-family="Times New Roman,serif" font-size="14.00">DWS.Task</text>
// </g>
// <!-- DWS.Task.Assignment&#45;&gt;DWS.Task -->
// <g id="edge1" class="edge">
// <title>DWS.Task.Assignment&#45;&gt;DWS.Task</title>
// <path fill="none" stroke="black" d="M96.84,-36.2C96.84,-47.84 96.84,-63.45 96.84,-76.76"/>
// <polygon fill="black" stroke="black" points="93.34,-76.82 96.84,-86.82 100.34,-76.82 93.34,-76.82"/>
// <text text-anchor="middle" x="108.34" y="-57.8" font-family="Times New Roman,serif" font-size="14.00">task</text>
// </g>
// <!-- DWS.Worker.Month -->
// <g id="node3" class="node">
// <title>DWS.Worker.Month</title>
// <ellipse fill="none" stroke="black" cx="256.84" cy="-105" rx="87.99" ry="18"/>
// <text text-anchor="middle" x="256.84" y="-101.3" font-family="Times New Roman,serif" font-size="14.00">DWS.Worker.Month</text>
// </g>
// <!-- DWS.Task.Assignment&#45;&gt;DWS.Worker.Month -->
// <g id="edge2" class="edge">
// <title>DWS.Task.Assignment&#45;&gt;DWS.Worker.Month</title>
// <path fill="none" stroke="black" d="M127.31,-35.19C152.97,-48.82 189.84,-68.41 217.69,-83.2"/>
// <polygon fill="black" stroke="black" points="216.28,-86.42 226.75,-88.02 219.57,-80.23 216.28,-86.42"/>
// <text text-anchor="middle" x="259.34" y="-57.8" font-family="Times New Roman,serif" font-size="14.00">assignedToWorkerMonth</text>
// </g>
// <!-- DWS.User -->
// <g id="node4" class="node">
// <title>DWS.User</title>
// <ellipse fill="none" stroke="black" cx="94.84" cy="-279" rx="50.89" ry="18"/>
// <text text-anchor="middle" x="94.84" y="-275.3" font-family="Times New Roman,serif" font-size="14.00">DWS.User</text>
// </g>
// <!-- DWS.Task.Assignment&#45;&gt;DWS.User -->
// <g id="edge3" class="edge">
// <title>DWS.Task.Assignment&#45;&gt;DWS.User</title>
// <path fill="none" stroke="black" d="M76.32,-35.8C62.47,-48.37 45.1,-66.82 35.84,-87 22.99,-115.02 21.28,-126.12 28.84,-156 38.01,-192.23 60.32,-229.36 76.46,-252.99"/>
// <polygon fill="black" stroke="black" points="73.71,-255.17 82.31,-261.36 79.45,-251.16 73.71,-255.17"/>
// <text text-anchor="middle" x="60.84" y="-144.8" font-family="Times New Roman,serif" font-size="14.00">assignedBy</text>
// </g>
// <!-- DWS.Task&#45;&gt;DWS.User -->
// <g id="edge5" class="edge">
// <title>DWS.Task&#45;&gt;DWS.User</title>
// <path fill="none" stroke="black" d="M96.64,-123.12C96.29,-153 95.58,-214.89 95.16,-250.73"/>
// <polygon fill="black" stroke="black" points="91.66,-250.91 95.04,-260.95 98.66,-250.99 91.66,-250.91"/>
// <text text-anchor="middle" x="138.34" y="-188.3" font-family="Times New Roman,serif" font-size="14.00">createdByUser</text>
// </g>
// <!-- DWS.Supplier.Month -->
// <g id="node5" class="node">
// <title>DWS.Supplier.Month</title>
// <ellipse fill="none" stroke="black" cx="427.84" cy="-192" rx="90.18" ry="18"/>
// <text text-anchor="middle" x="427.84" y="-188.3" font-family="Times New Roman,serif" font-size="14.00">DWS.Supplier.Month</text>
// </g>
// <!-- DWS.Task&#45;&gt;DWS.Supplier.Month -->
// <g id="edge4" class="edge">
// <title>DWS.Task&#45;&gt;DWS.Supplier.Month</title>
// <path fill="none" stroke="black" d="M135.29,-117.27C143.36,-119.38 151.84,-121.42 159.84,-123 221.82,-135.26 239.65,-125.31 300.84,-141 329.72,-148.4 360.88,-160.61 385.11,-171.1"/>
// <polygon fill="black" stroke="black" points="383.81,-174.35 394.37,-175.18 386.63,-167.95 383.81,-174.35"/>
// <text text-anchor="middle" x="387.84" y="-144.8" font-family="Times New Roman,serif" font-size="14.00">supplierMonth</text>
// </g>
// <!-- DWS.Worker -->
// <g id="node6" class="node">
// <title>DWS.Worker</title>
// <ellipse fill="none" stroke="black" cx="257.84" cy="-192" rx="61.99" ry="18"/>
// <text text-anchor="middle" x="257.84" y="-188.3" font-family="Times New Roman,serif" font-size="14.00">DWS.Worker</text>
// </g>
// <!-- DWS.Worker.Month&#45;&gt;DWS.Worker -->
// <g id="edge6" class="edge">
// <title>DWS.Worker.Month&#45;&gt;DWS.Worker</title>
// <path fill="none" stroke="black" d="M257.04,-123.2C257.18,-134.84 257.36,-150.45 257.52,-163.76"/>
// <polygon fill="black" stroke="black" points="254.02,-163.87 257.64,-173.82 261.02,-163.78 254.02,-163.87"/>
// <text text-anchor="middle" x="276.84" y="-144.8" font-family="Times New Roman,serif" font-size="14.00">worker</text>
// </g>
// <!-- DWS.Supplier -->
// <g id="node7" class="node">
// <title>DWS.Supplier</title>
// <ellipse fill="none" stroke="black" cx="317.84" cy="-279" rx="63.89" ry="18"/>
// <text text-anchor="middle" x="317.84" y="-275.3" font-family="Times New Roman,serif" font-size="14.00">DWS.Supplier</text>
// </g>
// <!-- DWS.Supplier.Month&#45;&gt;DWS.Supplier -->
// <g id="edge7" class="edge">
// <title>DWS.Supplier.Month&#45;&gt;DWS.Supplier</title>
// <path fill="none" stroke="black" d="M406.37,-209.59C389.38,-222.72 365.48,-241.19 346.8,-255.63"/>
// <polygon fill="black" stroke="black" points="344.66,-252.86 338.88,-261.74 348.94,-258.39 344.66,-252.86"/>
// <text text-anchor="middle" x="401.34" y="-231.8" font-family="Times New Roman,serif" font-size="14.00">supplier</text>
// </g>
// <!-- DWS.Worker&#45;&gt;DWS.User -->
// <g id="edge8" class="edge">
// <title>DWS.Worker&#45;&gt;DWS.User</title>
// <path fill="none" stroke="black" d="M229.08,-208C201.86,-222.19 160.9,-243.55 131.38,-258.94"/>
// <polygon fill="black" stroke="black" points="129.48,-255.99 122.23,-263.72 132.72,-262.19 129.48,-255.99"/>
// <text text-anchor="middle" x="198.84" y="-231.8" font-family="Times New Roman,serif" font-size="14.00">user</text>
// </g>
// <!-- DWS.Worker&#45;&gt;DWS.Supplier -->
// <g id="edge9" class="edge">
// <title>DWS.Worker&#45;&gt;DWS.Supplier</title>
// <path fill="none" stroke="black" d="M269.7,-209.79C278.41,-222.13 290.39,-239.11 300.22,-253.03"/>
// <polygon fill="black" stroke="black" points="297.39,-255.09 306.01,-261.24 303.1,-251.05 297.39,-255.09"/>
// <text text-anchor="middle" x="314.34" y="-231.8" font-family="Times New Roman,serif" font-size="14.00">Supplier</text>
// </g>
// </g>
// </svg>

// %%
var theAmazingSupplier = await j.Fact(new Supplier("---AmazSupPubKey---"));

var jan = await j.Fact(new User("---JansPubKey---"));
var michael = await j.Fact(new User("---MichaelsPubKey"));

var worker_jan = await j.Fact(new Worker(jan, theAmazingSupplier));
var dispatcher_michael = await j.Fact(new Dispatcher(michael, theAmazingSupplier));

var p_s_2021_10 =await j.Fact(new SupplierMonth(theAmazingSupplier,2021,10));
var p_w_2021_10 =await j.Fact(new WorkerMonth(worker_jan,2021,10));

var taskByDispatcher = await j.Fact(new Task(p_s_2021_10, dispatcher_michael.user, DateTime.Now));
var taskByWorker = await j.Fact(new Task(p_s_2021_10, worker_jan.user, DateTime.Now));

var assignedByDispatcher = await j.Fact( new TaskAssignment(taskByDispatcher, p_w_2021_10, dispatcher_michael.user ));
var assignedByWorker = await j.Fact( new TaskAssignment(taskByWorker, p_w_2021_10, worker_jan.user));


Jinaga.Graphviz.Renderer.RenderFacts(new object [] {assignedByDispatcher, assignedByWorker, dispatcher_michael})
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 2.49.1 (20210923.0004)
//  -->
// <!-- Pages: 1 -->
// <svg width="958pt" height="389pt"
//  viewBox="0.00 0.00 958.00 389.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 385)">
// <polygon fill="white" stroke="transparent" points="-4,4 -4,-385 954,-385 954,4 -4,4"/>
// <!-- 9DecPbd7fOUN5cS/6Oq0fnnfh89VVF/+X1VUY2mYsAjYjimJ81VBdo+Ha1YPcBHRnhWKA8n2fKEzXA/Nm4jhZw== -->
// <g id="node1" class="node">
// <title>9DecPbd7fOUN5cS/6Oq0fnnfh89VVF/+X1VUY2mYsAjYjimJ81VBdo+Ha1YPcBHRnhWKA8n2fKEzXA/Nm4jhZw==</title>
// <polygon fill="none" stroke="black" points="319,-356 319,-377 528,-377 528,-356 319,-356"/>
// <text text-anchor="start" x="382.5" y="-362.8" font-family="Times New Roman,serif" font-size="14.00">DWS.Supplier</text>
// <polygon fill="none" stroke="black" points="319,-335 319,-356 383,-356 383,-335 319,-335"/>
// <text text-anchor="start" x="322" y="-341.8" font-family="Times New Roman,serif" font-size="14.00">publicKey</text>
// <polygon fill="none" stroke="black" points="383,-335 383,-356 528,-356 528,-335 383,-335"/>
// <text text-anchor="start" x="386" y="-341.8" font-family="Times New Roman,serif" font-size="14.00">&quot;&#45;&#45;&#45;AmazSupPubKey&#45;&#45;&#45;&quot;</text>
// </g>
// <!-- kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg== -->
// <g id="node2" class="node">
// <title>kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg==</title>
// <polygon fill="none" stroke="black" points="359,-254.5 359,-275.5 488,-275.5 488,-254.5 359,-254.5"/>
// <text text-anchor="start" x="362" y="-261.3" font-family="Times New Roman,serif" font-size="14.00">DWS.Supplier.Month</text>
// <polygon fill="none" stroke="black" points="359,-233.5 359,-254.5 427,-254.5 427,-233.5 359,-233.5"/>
// <text text-anchor="start" x="381" y="-240.3" font-family="Times New Roman,serif" font-size="14.00">year</text>
// <polygon fill="none" stroke="black" points="427,-233.5 427,-254.5 488,-254.5 488,-233.5 427,-233.5"/>
// <text text-anchor="start" x="443.5" y="-240.3" font-family="Times New Roman,serif" font-size="14.00">2021</text>
// <polygon fill="none" stroke="black" points="359,-212.5 359,-233.5 427,-233.5 427,-212.5 359,-212.5"/>
// <text text-anchor="start" x="375" y="-219.3" font-family="Times New Roman,serif" font-size="14.00">month</text>
// <polygon fill="none" stroke="black" points="427,-212.5 427,-233.5 488,-233.5 488,-212.5 427,-212.5"/>
// <text text-anchor="start" x="450.5" y="-219.3" font-family="Times New Roman,serif" font-size="14.00">10</text>
// </g>
// <!-- kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg==&#45;&gt;9DecPbd7fOUN5cS/6Oq0fnnfh89VVF/+X1VUY2mYsAjYjimJ81VBdo+Ha1YPcBHRnhWKA8n2fKEzXA/Nm4jhZw== -->
// <g id="edge1" class="edge">
// <title>kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg==&#45;&gt;9DecPbd7fOUN5cS/6Oq0fnnfh89VVF/+X1VUY2mYsAjYjimJ81VBdo+Ha1YPcBHRnhWKA8n2fKEzXA/Nm4jhZw==</title>
// <path fill="none" stroke="black" d="M423,-280.15C423,-293.07 423,-307.73 423,-320.63"/>
// <polygon fill="black" stroke="black" points="419.5,-320.97 423,-330.97 426.5,-320.97 419.5,-320.97"/>
// <text text-anchor="middle" x="445.5" y="-301.8" font-family="Times New Roman,serif" font-size="14.00">supplier</text>
// </g>
// <!-- DdseEr/1A/4auyh3mUbOrB/kGTud8JHvZ9YkGWrnJixYyPFdGqN5IiHu8ZDldXVmGXdK2uHUF62nu7rlzPwcCg== -->
// <g id="node3" class="node">
// <title>DdseEr/1A/4auyh3mUbOrB/kGTud8JHvZ9YkGWrnJixYyPFdGqN5IiHu8ZDldXVmGXdK2uHUF62nu7rlzPwcCg==</title>
// <polygon fill="none" stroke="black" points="134,-244.5 134,-265.5 325,-265.5 325,-244.5 134,-244.5"/>
// <text text-anchor="start" x="198.5" y="-251.3" font-family="Times New Roman,serif" font-size="14.00">DWS.User</text>
// <polygon fill="none" stroke="black" points="134,-223.5 134,-244.5 198,-244.5 198,-223.5 134,-223.5"/>
// <text text-anchor="start" x="137" y="-230.3" font-family="Times New Roman,serif" font-size="14.00">publicKey</text>
// <polygon fill="none" stroke="black" points="198,-223.5 198,-244.5 325,-244.5 325,-223.5 198,-223.5"/>
// <text text-anchor="start" x="201" y="-230.3" font-family="Times New Roman,serif" font-size="14.00">&quot;&#45;&#45;&#45;MichaelsPubKey&quot;</text>
// </g>
// <!-- s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw== -->
// <g id="node4" class="node">
// <title>s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw==</title>
// <polygon fill="none" stroke="black" points="246,-122.5 246,-143.5 462,-143.5 462,-122.5 246,-122.5"/>
// <text text-anchor="start" x="322" y="-129.3" font-family="Times New Roman,serif" font-size="14.00">DWS.Task</text>
// <polygon fill="none" stroke="black" points="246,-101.5 246,-122.5 293,-122.5 293,-101.5 246,-101.5"/>
// <text text-anchor="start" x="249" y="-108.3" font-family="Times New Roman,serif" font-size="14.00">created</text>
// <polygon fill="none" stroke="black" points="293,-101.5 293,-122.5 462,-122.5 462,-101.5 293,-101.5"/>
// <text text-anchor="start" x="296" y="-108.3" font-family="Times New Roman,serif" font-size="14.00">&quot;2021&#45;10&#45;18T14:50:28.939Z&quot;</text>
// </g>
// <!-- s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw==&#45;&gt;kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg== -->
// <g id="edge2" class="edge">
// <title>s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw==&#45;&gt;kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg==</title>
// <path fill="none" stroke="black" d="M349.9,-147.52C348.74,-160.99 349.28,-177.71 356,-191 357.73,-194.43 359.81,-197.71 362.14,-200.83"/>
// <polygon fill="black" stroke="black" points="359.69,-203.35 368.83,-208.71 365.02,-198.82 359.69,-203.35"/>
// <text text-anchor="middle" x="397" y="-179.8" font-family="Times New Roman,serif" font-size="14.00">supplierMonth</text>
// </g>
// <!-- s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw==&#45;&gt;DdseEr/1A/4auyh3mUbOrB/kGTud8JHvZ9YkGWrnJixYyPFdGqN5IiHu8ZDldXVmGXdK2uHUF62nu7rlzPwcCg== -->
// <g id="edge3" class="edge">
// <title>s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw==&#45;&gt;DdseEr/1A/4auyh3mUbOrB/kGTud8JHvZ9YkGWrnJixYyPFdGqN5IiHu8ZDldXVmGXdK2uHUF62nu7rlzPwcCg==</title>
// <path fill="none" stroke="black" d="M301.36,-147.57C288.08,-155.33 274.6,-164.86 264,-176 254.74,-185.73 247.31,-198.4 241.72,-210.13"/>
// <polygon fill="black" stroke="black" points="238.52,-208.7 237.63,-219.25 244.91,-211.56 238.52,-208.7"/>
// <text text-anchor="middle" x="305.5" y="-179.8" font-family="Times New Roman,serif" font-size="14.00">createdByUser</text>
// </g>
// <!-- YLdq8DJOm8OE4EwEIddPY8OE+9DBxsdiDIQo1GCed96c+w6OG9vOI6hmD9l9J/RS9SrzcPDwGdL1ip392VgPbw== -->
// <g id="node5" class="node">
// <title>YLdq8DJOm8OE4EwEIddPY8OE+9DBxsdiDIQo1GCed96c+w6OG9vOI6hmD9l9J/RS9SrzcPDwGdL1ip392VgPbw==</title>
// <polygon fill="none" stroke="black" points="675,-356 675,-377 854,-377 854,-356 675,-356"/>
// <text text-anchor="start" x="733.5" y="-362.8" font-family="Times New Roman,serif" font-size="14.00">DWS.User</text>
// <polygon fill="none" stroke="black" points="675,-335 675,-356 739,-356 739,-335 675,-335"/>
// <text text-anchor="start" x="678" y="-341.8" font-family="Times New Roman,serif" font-size="14.00">publicKey</text>
// <polygon fill="none" stroke="black" points="739,-335 739,-356 854,-356 854,-335 739,-335"/>
// <text text-anchor="start" x="742" y="-341.8" font-family="Times New Roman,serif" font-size="14.00">&quot;&#45;&#45;&#45;JansPubKey&#45;&#45;&#45;&quot;</text>
// </g>
// <!-- F8Wx6ACvLtxLLyohjHdiU+saUOuA65k4m43yvV+a24dCPiNC06vBUg/A0wvFTDoIFBWe9KuL4+bP6F33JqDFoQ== -->
// <g id="node6" class="node">
// <title>F8Wx6ACvLtxLLyo

// %% [markdown]
// The next specification generates an error.
// Reason: It did NOT start from the most recent fact (=valley fact) involved in the query.  We started from "task", while we should have started from its successor "taskAssignment".

// %%
var tasksForWorker_0 = Given<Worker>.Match((worker, facts)=>
    from task in facts.OfType<Task>()
    where (
        from succ in facts.OfType<TaskAssignment>()
        where succ.assignedToWorkerMonth.worker == worker
        where succ.task == task
        select succ
    ).Any()
    select task
);
// Out:
// System.NotImplementedException: Cannot generate pipeline for Jinaga.Definitions.SetDefinitionTarget
//
//    at Jinaga.Generators.PipelineGenerator.CreatePipeline(SetDefinition setDefinition, SetDefinition seekSetDefinition, Label replaceLabel)
//
//    at Jinaga.Generators.SpecificationGenerator.CreateSpecification(SymbolValue value)
//
//    at Jinaga.Given`1.Match[TProjection](Func`3 spec)
//
//    at Submission#93.<<Initialize>>d__0.MoveNext()
//
// --- End of stack trace from previous location ---
//
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

// %% [markdown]
// So let's do it the right way and start from the most recent fact, "taskAssignment" :

// %%
var tasksForWorker_1 = Given<Worker>.Match((worker, facts)=>
    from taskAssignment in facts.OfType<TaskAssignment>()
    where taskAssignment.assignedToWorkerMonth.worker == worker
    select taskAssignment.task
);

tasksForWorker_1.Pipeline.ToDescriptiveString()
// Out:
// worker: DWS.Worker {
//     taskAssignment: DWS.Task.Assignment = worker S.worker DWS.Worker.Month S.assignedToWorkerMonth DWS.Task.Assignment
//     task: DWS.Task = taskAssignment P.task DWS.Task
// }

// %% [markdown]
// But you can do it also in this way.
// Note that the resulting pipeline is exactly the same as the previous one:

// %%
var tasksForWorker_2 = Given<Worker>.Match((worker, facts)=>
    from taskAssignment in facts.OfType<TaskAssignment>()
        where taskAssignment.assignedToWorkerMonth.worker == worker
    from task in facts.OfType<Task>()
        where taskAssignment.task == task
    select task
);

tasksForWorker_2.Pipeline.ToDescriptiveString()
// Out:
// worker: DWS.Worker {
//     taskAssignment: DWS.Task.Assignment = worker S.worker DWS.Worker.Month S.assignedToWorkerMonth DWS.Task.Assignment
//     task: DWS.Task = taskAssignment P.task DWS.Task
// }

// %% [markdown]
// Let's finally create the query:

// %%
var tasksForJan = await j.Query(worker_jan, tasksForWorker_1);

Jinaga.Graphviz.Renderer.RenderFacts(tasksForJan)
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 2.49.1 (20210923.0004)
//  -->
// <!-- Pages: 1 -->
// <svg width="591pt" height="283pt"
//  viewBox="0.00 0.00 591.00 283.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 279)">
// <polygon fill="white" stroke="transparent" points="-4,4 -4,-279 587,-279 587,4 -4,4"/>
// <!-- 9DecPbd7fOUN5cS/6Oq0fnnfh89VVF/+X1VUY2mYsAjYjimJ81VBdo+Ha1YPcBHRnhWKA8n2fKEzXA/Nm4jhZw== -->
// <g id="node1" class="node">
// <title>9DecPbd7fOUN5cS/6Oq0fnnfh89VVF/+X1VUY2mYsAjYjimJ81VBdo+Ha1YPcBHRnhWKA8n2fKEzXA/Nm4jhZw==</title>
// <polygon fill="none" stroke="black" points="193.5,-250 193.5,-271 402.5,-271 402.5,-250 193.5,-250"/>
// <text text-anchor="start" x="257" y="-256.8" font-family="Times New Roman,serif" font-size="14.00">DWS.Supplier</text>
// <polygon fill="none" stroke="black" points="193.5,-229 193.5,-250 257.5,-250 257.5,-229 193.5,-229"/>
// <text text-anchor="start" x="196.5" y="-235.8" font-family="Times New Roman,serif" font-size="14.00">publicKey</text>
// <polygon fill="none" stroke="black" points="257.5,-229 257.5,-250 402.5,-250 402.5,-229 257.5,-229"/>
// <text text-anchor="start" x="260.5" y="-235.8" font-family="Times New Roman,serif" font-size="14.00">&quot;&#45;&#45;&#45;AmazSupPubKey&#45;&#45;&#45;&quot;</text>
// </g>
// <!-- kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg== -->
// <g id="node2" class="node">
// <title>kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg==</title>
// <polygon fill="none" stroke="black" points="233.5,-148.5 233.5,-169.5 362.5,-169.5 362.5,-148.5 233.5,-148.5"/>
// <text text-anchor="start" x="236.5" y="-155.3" font-family="Times New Roman,serif" font-size="14.00">DWS.Supplier.Month</text>
// <polygon fill="none" stroke="black" points="233.5,-127.5 233.5,-148.5 301.5,-148.5 301.5,-127.5 233.5,-127.5"/>
// <text text-anchor="start" x="255.5" y="-134.3" font-family="Times New Roman,serif" font-size="14.00">year</text>
// <polygon fill="none" stroke="black" points="301.5,-127.5 301.5,-148.5 362.5,-148.5 362.5,-127.5 301.5,-127.5"/>
// <text text-anchor="start" x="318" y="-134.3" font-family="Times New Roman,serif" font-size="14.00">2021</text>
// <polygon fill="none" stroke="black" points="233.5,-106.5 233.5,-127.5 301.5,-127.5 301.5,-106.5 233.5,-106.5"/>
// <text text-anchor="start" x="249.5" y="-113.3" font-family="Times New Roman,serif" font-size="14.00">month</text>
// <polygon fill="none" stroke="black" points="301.5,-106.5 301.5,-127.5 362.5,-127.5 362.5,-106.5 301.5,-106.5"/>
// <text text-anchor="start" x="325" y="-113.3" font-family="Times New Roman,serif" font-size="14.00">10</text>
// </g>
// <!-- kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg==&#45;&gt;9DecPbd7fOUN5cS/6Oq0fnnfh89VVF/+X1VUY2mYsAjYjimJ81VBdo+Ha1YPcBHRnhWKA8n2fKEzXA/Nm4jhZw== -->
// <g id="edge1" class="edge">
// <title>kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg==&#45;&gt;9DecPbd7fOUN5cS/6Oq0fnnfh89VVF/+X1VUY2mYsAjYjimJ81VBdo+Ha1YPcBHRnhWKA8n2fKEzXA/Nm4jhZw==</title>
// <path fill="none" stroke="black" d="M297.5,-174.15C297.5,-187.07 297.5,-201.73 297.5,-214.63"/>
// <polygon fill="black" stroke="black" points="294,-214.97 297.5,-224.97 301,-214.97 294,-214.97"/>
// <text text-anchor="middle" x="320" y="-195.8" font-family="Times New Roman,serif" font-size="14.00">supplier</text>
// </g>
// <!-- DdseEr/1A/4auyh3mUbOrB/kGTud8JHvZ9YkGWrnJixYyPFdGqN5IiHu8ZDldXVmGXdK2uHUF62nu7rlzPwcCg== -->
// <g id="node3" class="node">
// <title>DdseEr/1A/4auyh3mUbOrB/kGTud8JHvZ9YkGWrnJixYyPFdGqN5IiHu8ZDldXVmGXdK2uHUF62nu7rlzPwcCg==</title>
// <polygon fill="none" stroke="black" points="8.5,-138.5 8.5,-159.5 199.5,-159.5 199.5,-138.5 8.5,-138.5"/>
// <text text-anchor="start" x="73" y="-145.3" font-family="Times New Roman,serif" font-size="14.00">DWS.User</text>
// <polygon fill="none" stroke="black" points="8.5,-117.5 8.5,-138.5 72.5,-138.5 72.5,-117.5 8.5,-117.5"/>
// <text text-anchor="start" x="11.5" y="-124.3" font-family="Times New Roman,serif" font-size="14.00">publicKey</text>
// <polygon fill="none" stroke="black" points="72.5,-117.5 72.5,-138.5 199.5,-138.5 199.5,-117.5 72.5,-117.5"/>
// <text text-anchor="start" x="75.5" y="-124.3" font-family="Times New Roman,serif" font-size="14.00">&quot;&#45;&#45;&#45;MichaelsPubKey&quot;</text>
// </g>
// <!-- s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw== -->
// <g id="node4" class="node">
// <title>s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw==</title>
// <polygon fill="none" stroke="black" points="53.5,-26 53.5,-47 269.5,-47 269.5,-26 53.5,-26"/>
// <text text-anchor="start" x="129.5" y="-32.8" font-family="Times New Roman,serif" font-size="14.00">DWS.Task</text>
// <polygon fill="none" stroke="black" points="53.5,-5 53.5,-26 100.5,-26 100.5,-5 53.5,-5"/>
// <text text-anchor="start" x="56.5" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">created</text>
// <polygon fill="none" stroke="black" points="100.5,-5 100.5,-26 269.5,-26 269.5,-5 100.5,-5"/>
// <text text-anchor="start" x="103.5" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">&quot;2021&#45;10&#45;18T14:50:28.939Z&quot;</text>
// <polygon fill="none" stroke="black" points="52.5,-4 52.5,-48 270.5,-48 270.5,-4 52.5,-4"/>
// </g>
// <!-- s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw==&#45;&gt;kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg== -->
// <g id="edge2" class="edge">
// <title>s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw==&#45;&gt;kRlo4/HGSQ8Rqt25Prg1qVR6CHccTIRo6cTeMXX+XuMAHS6d1X/q2Qcq+frVA+e1tCENliJLvutkOtaJqd2NOg==</title>
// <path fill="none" stroke="black" d="M192.36,-52.07C208.4,-65.11 228.42,-81.37 246.67,-96.2"/>
// <polygon fill="black" stroke="black" points="244.94,-99.3 254.91,-102.89 249.35,-93.87 244.94,-99.3"/>
// <text text-anchor="middle" x="270.5" y="-73.8" font-family="Times New Roman,serif" font-size="14.00">supplierMonth</text>
// </g>
// <!-- s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw==&#45;&gt;DdseEr/1A/4auyh3mUbOrB/kGTud8JHvZ9YkGWrnJixYyPFdGqN5IiHu8ZDldXVmGXdK2uHUF62nu7rlzPwcCg== -->
// <g id="edge3" class="edge">
// <title>s9eAviohYb52wv00UQONePSS4MHqdzc0tuNVmh4RZOoyfNXwTvxFjCOf+48c5el5EbgFC58Ccf2grPGGskyLKw==&#45;&gt;DdseEr/1A/4auyh3mUbOrB/kGTud8JHvZ9YkGWrnJixYyPFdGqN5IiHu8ZDldXVmGXdK2uHUF62nu7rlzPwcCg==</title>
// <path fill="none" stroke="black" d="M128,-52.29C122.78,-57.61 117.97,-63.58 114.5,-70 109.06,-80.05 106.16,-92.09 104.65,-103.19"/>
// <polygon fill="black" stroke="black" points="101.14,-103.15 103.6,-113.46 108.1,-103.87 101.14,-103.15"/>
// <text text-anchor="middle" x="156" y="-73.8" font-family="Times New Roman,serif" font-size="14.00">createdByUser</text>
// </g>
// <!-- YLdq8DJOm8OE4EwEIddPY8OE+9DBxsdiDIQo1GCed96c+w6OG9vOI6hmD9l9J/RS9SrzcPDwGdL1ip392VgPbw== -->
// <g id="node5" class="node">
// <title>YLdq8DJOm8OE4EwEIddPY8OE+9DBxsdiDIQo1GCed96c+w6OG9vOI6hmD9l9J/RS9SrzcPDwGdL1ip392VgPbw==</title>
// <polygon fill="none" stroke="black" points="396.5,-138.5 396.5,-159.5 575.5,-159.5 575.5,-138.5 396.5,-138.5"/>
// <text text-anchor="start" x="455" y="-145.3" font-family="Times New Roman,serif" font-size="14.00">DWS.User</text>
// <polygon fill="none" stroke="black" points="396.5,-117.5 396.5,-138.5 460.5,-138.5 460.5,-117.5 396.5,-117.5"/>
// <text text-anchor="start" x="399.5" y="-124.3" font-family="Times New Roman,serif" font-size="14.00">publicKey</text>
// <polygon fill="none" stroke="black" points="460.5,-117.5 460.5,-138.5 575.5,-138.5 575.5,-117.5 460.5,-117.5"/>
// <text text-anchor="start" x="463.5" y="-124.3" font-family="Times New Roman,serif" font-size="14.00">&quot;&#45;&#45;&#45;JansPubKey&#45;&#45;&#
