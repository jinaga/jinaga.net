# %% [markdown]
# # CoLab
#
# Colaborative project management.

# %%
#r "nuget: Jinaga, 0.5.1"
#r "nuget: Jinaga.Graphviz, 0.5.1"

using Jinaga;
using Jinaga.Graphviz;
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga, 0.5.1</span></li><li><span>Jinaga.Graphviz, 0.5.1</span></li></ul></div></div>

# %%
var j = JinagaClient.Create(opt =>
{
  opt.HttpEndpoint = new Uri("https://repdev.jinaga.com/Ds2dfHlKFKAL7aiEbZViyYmhwhVXSvuxAbEGfMaNqEGK8PE6WNk-z3k_-kQmiuLPg1ybeXA04wlM6myEyIbczA");
});

# %% [markdown]
# A user creates a project.
# The project has a name.

# %%
[FactType("Jinaga.User")]
public record User(string publicKey) {}

[FactType("CoLab.Project")]
public record Project(User creator, DateTime createdAt) {}

[FactType("CoLab.Project.Name")]
public record ProjectName(Project project, string value, ProjectName[] prior) {}

Renderer.RenderTypes(typeof(User), typeof(Project), typeof(ProjectName))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 8.0.5 (20230430.1635)
#  -->
# <!-- Pages: 1 -->
# <svg width="232pt" height="220pt"
#  viewBox="0.00 0.00 231.97 219.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 215.5)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-215.5 227.97,-215.5 227.97,4 -4,4"/>
# <!-- CoLab.Project -->
# <g id="node1" class="node">
# <title>CoLab.Project</title>
# <ellipse fill="none" stroke="black" cx="89.49" cy="-105.75" rx="65.53" ry="18"/>
# <text text-anchor="middle" x="89.49" y="-100.33" font-family="Times New Roman,serif" font-size="14.00">CoLab.Project</text>
# </g>
# <!-- Jinaga.User -->
# <g id="node2" class="node">
# <title>Jinaga.User</title>
# <ellipse fill="none" stroke="black" cx="89.49" cy="-193.5" rx="53.06" ry="18"/>
# <text text-anchor="middle" x="89.49" y="-188.07" font-family="Times New Roman,serif" font-size="14.00">Jinaga.User</text>
# </g>
# <!-- CoLab.Project&#45;&gt;Jinaga.User -->
# <g id="edge1" class="edge">
# <title>CoLab.Project&#45;&gt;Jinaga.User</title>
# <path fill="none" stroke="black" d="M89.49,-124.1C89.49,-135.61 89.49,-150.97 89.49,-164.22"/>
# <polygon fill="black" stroke="black" points="85.99,-164.17 89.49,-174.17 92.99,-164.17 85.99,-164.17"/>
# <text text-anchor="middle" x="108.99" y="-144.2" font-family="Times New Roman,serif" font-size="14.00">creator</text>
# </g>
# <!-- CoLab.Project.Name -->
# <g id="node3" class="node">
# <title>CoLab.Project.Name</title>
# <ellipse fill="none" stroke="black" cx="89.49" cy="-18" rx="89.49" ry="18"/>
# <text text-anchor="middle" x="89.49" y="-12.57" font-family="Times New Roman,serif" font-size="14.00">CoLab.Project.Name</text>
# </g>
# <!-- CoLab.Project.Name&#45;&gt;CoLab.Project -->
# <g id="edge2" class="edge">
# <title>CoLab.Project.Name&#45;&gt;CoLab.Project</title>
# <path fill="none" stroke="black" d="M89.49,-36.35C89.49,-47.86 89.49,-63.22 89.49,-76.47"/>
# <polygon fill="black" stroke="black" points="85.99,-76.42 89.49,-86.42 92.99,-76.42 85.99,-76.42"/>
# <text text-anchor="middle" x="108.99" y="-56.45" font-family="Times New Roman,serif" font-size="14.00">project</text>
# </g>
# <!-- CoLab.Project.Name&#45;&gt;CoLab.Project.Name -->
# <g id="edge3" class="edge">
# <title>CoLab.Project.Name&#45;&gt;CoLab.Project.Name</title>
# <path fill="none" stroke="black" d="M171.04,-10.2C186.26,-11.16 196.97,-13.76 196.97,-18 196.97,-21.15 191.07,-23.39 181.81,-24.73"/>
# <polygon fill="black" stroke="black" points="181.64,-21.33 172.04,-25.8 182.34,-28.3 181.64,-21.33"/>
# <text text-anchor="middle" x="210.47" y="-12.57" font-family="Times New Roman,serif" font-size="14.00">prior</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# For example, a user creates a project called "Wingman".

# %%
var michael = await j.Fact(new User("---PUBLIC KEY---Michael---END PUBLIC KEY---"));
var wingman = await j.Fact(new Project(michael, DateTime.Parse("2021-04-01T13:00:00.000Z")));
var wingmanName = await j.Fact(new ProjectName(wingman, "Wingman", new ProjectName[0]));

Renderer.RenderFacts(wingmanName)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 8.0.5 (20230430.1635)
#  -->
# <!-- Pages: 1 -->
# <svg width="384pt" height="264pt"
#  viewBox="0.00 0.00 384.00 263.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 259.5)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-259.5 380,-259.5 380,4 -4,4"/>
# <!-- 0NfcyT0eNFLZeTI9PNKuNErbpb6qJ0FwwAlF9oXtZhsAR9yAaRinqzYQpv7AfPKztyrUdSr0hdbdTO6ssHEYRA== -->
# <g id="node1" class="node">
# <title>0NfcyT0eNFLZeTI9PNKuNErbpb6qJ0FwwAlF9oXtZhsAR9yAaRinqzYQpv7AfPKztyrUdSr0hdbdTO6ssHEYRA==</title>
# <polygon fill="none" stroke="black" points="8,-230.5 8,-251.5 368,-251.5 368,-230.5 8,-230.5"/>
# <text text-anchor="start" x="156.12" y="-235.2" font-family="Times New Roman,serif" font-size="14.00">Jinaga.User</text>
# <polygon fill="none" stroke="black" points="8,-209.5 8,-230.5 71,-230.5 71,-209.5 8,-209.5"/>
# <text text-anchor="start" x="11" y="-214.2" font-family="Times New Roman,serif" font-size="14.00">publicKey</text>
# <polygon fill="none" stroke="black" points="71,-209.5 71,-230.5 368,-230.5 368,-209.5 71,-209.5"/>
# <text text-anchor="start" x="74" y="-214.2" font-family="Times New Roman,serif" font-size="14.00">&#45;&#45;&#45;PUBLIC KEY&#45;&#45;&#45;Michael&#45;&#45;&#45;END PUBLIC KEY&#45;&#45;&#45;</text>
# </g>
# <!-- IRQOxr9cNxG5UR31sC5j7tvjRxEJOkZzS5eFfUAUSFbmqOOm7pCiAY7qj270pXZKZNk7b8p/17MhafHunIAp5w== -->
# <g id="node2" class="node">
# <title>IRQOxr9cNxG5UR31sC5j7tvjRxEJOkZzS5eFfUAUSFbmqOOm7pCiAY7qj270pXZKZNk7b8p/17MhafHunIAp5w==</title>
# <polygon fill="none" stroke="black" points="80,-128.75 80,-149.75 296,-149.75 296,-128.75 80,-128.75"/>
# <text text-anchor="start" x="146.75" y="-133.45" font-family="Times New Roman,serif" font-size="14.00">CoLab.Project</text>
# <polygon fill="none" stroke="black" points="80,-107.75 80,-128.75 140,-128.75 140,-107.75 80,-107.75"/>
# <text text-anchor="start" x="83" y="-112.45" font-family="Times New Roman,serif" font-size="14.00">createdAt</text>
# <polygon fill="none" stroke="black" points="140,-107.75 140,-128.75 296,-128.75 296,-107.75 140,-107.75"/>
# <text text-anchor="start" x="142.62" y="-112.45" font-family="Times New Roman,serif" font-size="14.00">2021&#45;04&#45;01T13:00:00.000Z</text>
# </g>
# <!-- IRQOxr9cNxG5UR31sC5j7tvjRxEJOkZzS5eFfUAUSFbmqOOm7pCiAY7qj270pXZKZNk7b8p/17MhafHunIAp5w==&#45;&gt;0NfcyT0eNFLZeTI9PNKuNErbpb6qJ0FwwAlF9oXtZhsAR9yAaRinqzYQpv7AfPKztyrUdSr0hdbdTO6ssHEYRA== -->
# <g id="edge1" class="edge">
# <title>IRQOxr9cNxG5UR31sC5j7tvjRxEJOkZzS5eFfUAUSFbmqOOm7pCiAY7qj270pXZKZNk7b8p/17MhafHunIAp5w==&#45;&gt;0NfcyT0eNFLZeTI9PNKuNErbpb6qJ0FwwAlF9oXtZhsAR9yAaRinqzYQpv7AfPKztyrUdSr0hdbdTO6ssHEYRA==</title>
# <path fill="none" stroke="black" d="M188,-153.64C188,-165.98 188,-181.26 188,-194.87"/>
# <polygon fill="black" stroke="black" points="184.5,-194.8 188,-204.8 191.5,-194.8 184.5,-194.8"/>
# <text text-anchor="middle" x="207.5" y="-174.2" font-family="Times New Roman,serif" font-size="14.00">creator</text>
# </g>
# <!-- M33y/zXWI8wlTqD6znepIS3dK81W0WafX6ztZEYa97aa+BMstygG6Ydsu0EOpiawUAdcrwJZvuZ3Mi/jxIujHg== -->
# <g id="node3" class="node">
# <title>M33y/zXWI8wlTqD6znepIS3dK81W0WafX6ztZEYa97aa+BMstygG6Ydsu0EOpiawUAdcrwJZvuZ3Mi/jxIujHg==</title>
# <polygon fill="none" stroke="black" points="126,-26 126,-47 250,-47 250,-26 126,-26"/>
# <text text-anchor="start" x="128.75" y="-30.7" font-family="Times New Roman,serif" font-size="14.00">CoLab.Project.Name</text>
# <polygon fill="none" stroke="black" points="126,-5 126,-26 175,-26 175,-5 126,-5"/>
# <text text-anchor="start" x="136.25" y="-9.7" font-family="Times New Roman,serif" font-size="14.00">value</text>
# <polygon fill="none" stroke="black" points="175,-5 175,-26 250,-26 250,-5 175,-5"/>
# <text text-anchor="start" x="185.88" y="-9.7" font-family="Times New Roman,serif" font-size="14.00">Wingman</text>
# <polygon fill="none" stroke="black" points="125,-4 125,-48 251,-48 251,-4 125,-4"/>
# </g>
# <!-- M33y/zXWI8wlTqD6znepIS3dK81W0WafX6ztZEYa97aa+BMstygG6Ydsu0EOpiawUAdcrwJZvuZ3Mi/jxIujHg==&#45;&gt;IRQOxr9cNxG5UR31sC5j7tvjRxEJOkZzS5eFfUAUSFbmqOOm7pCiAY7qj270pXZKZNk7b8p/17MhafHunIAp5w== -->
# <g id="edge2" class="edge">
# <title>M33y/zXWI8wlTqD6znepIS3dK81W0WafX6ztZEYa97aa+BMstygG6Ydsu0EOpiawUAdcrwJZvuZ3Mi/jxIujHg==&#45;&gt;IRQOxr9cNxG5UR31sC5j7tvjRxEJOkZzS5eFfUAUSFbmqOOm7pCiAY7qj270pXZKZNk7b8p/17MhafHunIAp5w==</title>
# <path fill="none" stroke="black" d="M188,-51.9C188,-64.29 188,-79.46 188,-92.97"/>
# <polygon fill="black" stroke="black" points="184.5,-92.83 188,-102.83 191.5,-92.83 184.5,-92.83"/>
# <text text-anchor="middle" x="207.5" y="-72.45" font-family="Times New Roman,serif" font-size="14.00">project</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Run a projection to list the projects.

# %%
var projectsFromUser = Given<User>.Match((user, facts) =>
  from project in facts.OfType<Project>()
  where project.creator == user
  select new {
    createdAt = project.createdAt,
    names =
      from name in facts.OfType<ProjectName>()
      where name.project == project &&
        !facts.Any<ProjectName>(next => next.prior.Contains(name))
      select name.value
  }
);

var projects = await j.Query(projectsFromUser, michael);

projects
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ createdAt = 4/1/2021 1:00:00 PM, names = System.Linq.Enumerable+&lt;OfTypeIterator&gt;d__65`1[System.String] }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>createdAt</td><td><span>2021-04-01 13:00:00Z</span></td></tr><tr><td>names</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ Wingman ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td><i>(values)</i></td><td><div class="dni-plaintext"><pre>[ Wingman ]</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
Renderer.RenderFacts(projects)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 8.0.5 (20230430.1635)
#  -->
# <!-- Pages: 1 -->
# <svg width="8pt" height="8pt"
#  viewBox="0.00 0.00 8.00 8.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 4)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-4 4,-4 4,4 -4,4"/>
# </g>
# </svg>
