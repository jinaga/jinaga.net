// %%
#r "nuget: Jinaga.UnitTest"
#r "nuget: Jinaga.Graphviz"
using Jinaga;
using Jinaga.UnitTest;
using Jinaga.Graphviz;

var j = JinagaTest.Create();
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga.Graphviz, 0.4.0</span></li><li><span>Jinaga.UnitTest, 0.4.0</span></li></ul></div></div>

// %%
[FactType("Restaurant.Server")]
record Server(string identifier) {}

[FactType("Restaurant.Table")]
record Table(int tableNumber) {}

[FactType("Restaurant.TableAssignment")]
record TableAssignment(Server server, Table table) {}

[FactType("Restaurant.Party")]
record Party(DateTime arrival) {}

[FactType("Restaurant.PartySeated")]
record PartySeated(Party party, Table table) {}


Jinaga.Graphviz.Renderer.RenderTypes(typeof(TableAssignment), typeof(PartySeated))
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 8.0.2 (20230410.1723)
//  -->
// <!-- Pages: 1 -->
// <svg width="495pt" height="131pt"
//  viewBox="0.00 0.00 495.23 131.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 127)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-127 491.23,-127 491.23,4 -4,4"/>
// <!-- Restaurant.TableAssignment -->
// <g id="node1" class="node">
// <title>Restaurant.TableAssignment</title>
// <ellipse fill="none" stroke="black" cx="114.39" cy="-18" rx="114.28" ry="18"/>
// <text text-anchor="middle" x="114.39" y="-14.3" font-family="Times New Roman,serif" font-size="14.00">Restaurant.TableAssignment</text>
// </g>
// <!-- Restaurant.Server -->
// <g id="node2" class="node">
// <title>Restaurant.Server</title>
// <ellipse fill="none" stroke="black" cx="89.39" cy="-105" rx="75.29" ry="18"/>
// <text text-anchor="middle" x="89.39" y="-101.3" font-family="Times New Roman,serif" font-size="14.00">Restaurant.Server</text>
// </g>
// <!-- Restaurant.TableAssignment&#45;&gt;Restaurant.Server -->
// <g id="edge1" class="edge">
// <title>Restaurant.TableAssignment&#45;&gt;Restaurant.Server</title>
// <path fill="none" stroke="black" d="M109.33,-36.2C105.94,-47.72 101.41,-63.14 97.52,-76.37"/>
// <polygon fill="black" stroke="black" points="93.91,-75.24 94.44,-85.82 100.62,-77.22 93.91,-75.24"/>
// <text text-anchor="middle" x="120.39" y="-57.8" font-family="Times New Roman,serif" font-size="14.00">server</text>
// </g>
// <!-- Restaurant.Table -->
// <g id="node3" class="node">
// <title>Restaurant.Table</title>
// <ellipse fill="none" stroke="black" cx="255.39" cy="-105" rx="72.29" ry="18"/>
// <text text-anchor="middle" x="255.39" y="-101.3" font-family="Times New Roman,serif" font-size="14.00">Restaurant.Table</text>
// </g>
// <!-- Restaurant.TableAssignment&#45;&gt;Restaurant.Table -->
// <g id="edge2" class="edge">
// <title>Restaurant.TableAssignment&#45;&gt;Restaurant.Table</title>
// <path fill="none" stroke="black" d="M142.25,-35.79C164.35,-49.12 195.42,-67.85 219.41,-82.31"/>
// <polygon fill="black" stroke="black" points="217.18,-85.65 227.55,-87.82 220.79,-79.66 217.18,-85.65"/>
// <text text-anchor="middle" x="206.89" y="-57.8" font-family="Times New Roman,serif" font-size="14.00">table</text>
// </g>
// <!-- Restaurant.PartySeated -->
// <g id="node4" class="node">
// <title>Restaurant.PartySeated</title>
// <ellipse fill="none" stroke="black" cx="391.39" cy="-18" rx="94.78" ry="18"/>
// <text text-anchor="middle" x="391.39" y="-14.3" font-family="Times New Roman,serif" font-size="14.00">Restaurant.PartySeated</text>
// </g>
// <!-- Restaurant.PartySeated&#45;&gt;Restaurant.Table -->
// <g id="edge4" class="edge">
// <title>Restaurant.PartySeated&#45;&gt;Restaurant.Table</title>
// <path fill="none" stroke="black" d="M364.84,-35.59C343.65,-48.84 313.76,-67.52 290.57,-82.01"/>
// <polygon fill="black" stroke="black" points="289.03,-79.47 282.41,-87.74 292.74,-85.41 289.03,-79.47"/>
// <text text-anchor="middle" x="345.89" y="-57.8" font-family="Times New Roman,serif" font-size="14.00">table</text>
// </g>
// <!-- Restaurant.Party -->
// <g id="node5" class="node">
// <title>Restaurant.Party</title>
// <ellipse fill="none" stroke="black" cx="416.39" cy="-105" rx="70.69" ry="18"/>
// <text text-anchor="middle" x="416.39" y="-101.3" font-family="Times New Roman,serif" font-size="14.00">Restaurant.Party</text>
// </g>
// <!-- Restaurant.PartySeated&#45;&gt;Restaurant.Party -->
// <g id="edge3" class="edge">
// <title>Restaurant.PartySeated&#45;&gt;Restaurant.Party</title>
// <path fill="none" stroke="black" d="M396.45,-36.2C399.84,-47.72 404.37,-63.14 408.26,-76.37"/>
// <polygon fill="black" stroke="black" points="405.16,-77.22 411.34,-85.82 411.87,-75.24 405.16,-77.22"/>
// <text text-anchor="middle" x="419.89" y="-57.8" font-family="Times New Roman,serif" font-size="14.00">party</text>
// </g>
// </g>
// </svg>

// %% [markdown]
// We want to find out which parties are served by which server.
// In this case we have 2 valley-facts (tableAssignment and partySeated). So which one to start from ?
// Start from both and link them together with a "where" clause.

// %%
var partiesServedBy_1 = Given<Server>.Match((server, facts) => 
    from tableAssignment in facts.OfType<TableAssignment>()
        where tableAssignment.server == server
    from partySeated in facts.OfType<PartySeated>()
        where partySeated.table == tableAssignment.table
    from party in facts.OfType<Party>()
        where party == partySeated.party
    select party
);

partiesServedBy_1.ToString()
// Out:
// (server: Restaurant.Server) {
//     tableAssignment: Restaurant.TableAssignment [
//         tableAssignment->server: Restaurant.Server = server
//     ]
//     partySeated: Restaurant.PartySeated [
//         partySeated->table: Restaurant.Table = tableAssignment->table: Restaurant.Table
//     ]
//     party: Restaurant.Party [
//         party = partySeated->party: Restaurant.Party
//     ]
// } => party

// %% [markdown]
// Note that OfType<T> has an overload which allows you to omit the "where" clause.....

// %%
var partiesServedBy_2 = Given<Server>.Match((server, facts) => 
    from tableAssignment in facts.OfType<TableAssignment>(
        tableAssignment => tableAssignment.server == server)
    from partySeated in facts.OfType<PartySeated>(
        partySeated => partySeated.table == tableAssignment.table)
    from party in facts.OfType<Party>(
        party => party == partySeated.party)
    select party
);

partiesServedBy_2.ToString()
// Out:
// (server: Restaurant.Server) {
//     tableAssignment: Restaurant.TableAssignment [
//         tableAssignment->server: Restaurant.Server = server
//     ]
//     partySeated: Restaurant.PartySeated [
//         partySeated->table: Restaurant.Table = tableAssignment->table: Restaurant.Table
//     ]
//     party: Restaurant.Party [
//         party = partySeated->party: Restaurant.Party
//     ]
// } => party
