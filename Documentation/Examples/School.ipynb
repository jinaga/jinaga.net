# %%
#r "nuget: Jinaga"
#r "nuget: Jinaga.UnitTest"
#r "nuget: Jinaga.Graphviz"
using Jinaga;
using Jinaga.UnitTest;
using Jinaga.Graphviz;

var j = JinagaClient.Create();
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga, 0.4.0</span></li><li><span>Jinaga.Graphviz, 0.4.0</span></li><li><span>Jinaga.UnitTest, 0.4.0</span></li></ul></div></div>

# %% [markdown]
# # School Example
#
# Jinaga.NET is a data management library for .NET.
# It captures facts that represent decisions that a user has made.
# Then it uses specifications to turn those facts into projections that appear on the user interface.
#
# Let's start with a model of a school offering courses.
# Both the school and the course are types of facts.

# %%
[FactType("School")]
public record School(string name) {}

[FactType("Course")]
public record Course(School school, string identifier) {}

Renderer.RenderTypes(typeof(School), typeof(Course))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.49.3 (20211023.0002)
#  -->
# <!-- Pages: 1 -->
# <svg width="83pt" height="131pt"
#  viewBox="0.00 0.00 83.05 131.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 127)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-127 79.05,-127 79.05,4 -4,4"/>
# <!-- Course -->
# <g id="node1" class="node">
# <title>Course</title>
# <ellipse fill="none" stroke="black" cx="37.05" cy="-18" rx="37.09" ry="18"/>
# <text text-anchor="middle" x="37.05" y="-14.3" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# </g>
# <!-- School -->
# <g id="node2" class="node">
# <title>School</title>
# <ellipse fill="none" stroke="black" cx="37.05" cy="-105" rx="36.29" ry="18"/>
# <text text-anchor="middle" x="37.05" y="-101.3" font-family="Times New Roman,serif" font-size="14.00">School</text>
# </g>
# <!-- Course&#45;&gt;School -->
# <g id="edge1" class="edge">
# <title>Course&#45;&gt;School</title>
# <path fill="none" stroke="black" d="M37.05,-36.2C37.05,-47.84 37.05,-63.45 37.05,-76.76"/>
# <polygon fill="black" stroke="black" points="33.55,-76.82 37.05,-86.82 40.55,-76.82 33.55,-76.82"/>
# <text text-anchor="middle" x="56.05" y="-57.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Suppose that the model contained the following facts.

# %%
var lps = await j.Fact(new School("LPS Frisco"));
var algebra = await j.Fact(new Course(lps, "MATH 101"));
var geometry = await j.Fact(new Course(lps, "MATH 102"));
var trigonometry = await j.Fact(new Course(lps, "MATH 201"));
var calculus = await j.Fact(new Course(lps, "MATH 301"));

Renderer.RenderFacts(algebra, geometry, trigonometry, calculus)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.49.3 (20211023.0002)
#  -->
# <!-- Pages: 1 -->
# <svg width="638pt" height="161pt"
#  viewBox="0.00 0.00 638.00 161.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 157)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-157 634,-157 634,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="262,-128 262,-149 369,-149 369,-128 262,-128"/>
# <text text-anchor="start" x="295.5" y="-134.8" font-family="Times New Roman,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="262,-107 262,-128 298,-128 298,-107 262,-107"/>
# <text text-anchor="start" x="265" y="-113.8" font-family="Times New Roman,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="298,-107 298,-128 369,-128 369,-107 298,-107"/>
# <text text-anchor="start" x="301" y="-113.8" font-family="Times New Roman,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="9,-26 9,-47 135,-47 135,-26 9,-26"/>
# <text text-anchor="start" x="51.5" y="-32.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="9,-5 9,-26 64,-26 64,-5 9,-5"/>
# <text text-anchor="start" x="12" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="64,-5 64,-26 135,-26 135,-5 64,-5"/>
# <text text-anchor="start" x="67" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">MATH 101</text>
# <polygon fill="none" stroke="black" points="8,-4 8,-48 136,-48 136,-4 8,-4"/>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M133.01,-52.11C167.72,-66.39 211.28,-84.32 247.08,-99.05"/>
# <polygon fill="black" stroke="black" points="245.9,-102.35 256.48,-102.92 248.57,-95.88 245.9,-102.35"/>
# <text text-anchor="middle" x="228" y="-73.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg== -->
# <g id="node3" class="node">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==</title>
# <polygon fill="none" stroke="black" points="171,-26 171,-47 297,-47 297,-26 171,-26"/>
# <text text-anchor="start" x="213.5" y="-32.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="171,-5 171,-26 226,-26 226,-5 171,-5"/>
# <text text-anchor="start" x="174" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="226,-5 226,-26 297,-26 297,-5 226,-5"/>
# <text text-anchor="start" x="229" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">MATH 102</text>
# <polygon fill="none" stroke="black" points="170,-4 170,-48 298,-48 298,-4 170,-4"/>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge2" class="edge">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M254.44,-52.23C264.94,-65.2 277.85,-81.13 289.04,-94.95"/>
# <polygon fill="black" stroke="black" points="286.39,-97.24 295.41,-102.81 291.83,-92.84 286.39,-97.24"/>
# <text text-anchor="middle" x="299" y="-73.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="node4" class="node">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <polygon fill="none" stroke="black" points="333,-26 333,-47 459,-47 459,-26 333,-26"/>
# <text text-anchor="start" x="375.5" y="-32.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="333,-5 333,-26 388,-26 388,-5 333,-5"/>
# <text text-anchor="start" x="336" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="388,-5 388,-26 459,-26 459,-5 388,-5"/>
# <text text-anchor="start" x="391" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">MATH 201</text>
# <polygon fill="none" stroke="black" points="332,-4 332,-48 460,-48 460,-4 332,-4"/>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge3" class="edge">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M375.56,-52.23C365.06,-65.2 352.15,-81.13 340.96,-94.95"/>
# <polygon fill="black" stroke="black" points="338.17,-92.84 334.59,-102.81 343.61,-97.24 338.17,-92.84"/>
# <text text-anchor="middle" x="380" y="-73.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ== -->
# <g id="node5" class="node">
# <title>kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ==</title>
# <polygon fill="none" stroke="black" points="495,-26 495,-47 621,-47 621,-26 495,-26"/>
# <text text-anchor="start" x="537.5" y="-32.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="495,-5 495,-26 550,-26 550,-5 495,-5"/>
# <text text-anchor="start" x="498" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="550,-5 550,-26 621,-26 621,-5 550,-5"/>
# <text text-anchor="start" x="553" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">MATH 301</text>
# <polygon fill="none" stroke="black" points="494,-4 494,-48 622,-48 622,-4 494,-4"/>
# </g>
# <!-- kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge4" class="edge">
# <title>kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M496.99,-52.11C462.28,-66.39 418.72,-84.32 382.92,-99.05"/>
# <polygon fill="black" stroke="black" points="381.43,-95.88 373.52,-102.92 384.1,-102.35 381.43,-95.88"/>
# <text text-anchor="middle" x="470" y="-73.8" font-family="Times New Roman,serif" font-size="14.00

# %% [markdown]
# This forms a graph.
# Each fact points up to its predecessor.
# The school was founded before it offered courses.
# The courses, however, are not related to each other.
#
# Given these facts, we can write a specification to return the catalog of courses offered by the school.

# %%
var coursesInSchool = Given<School>.Match((school, facts) =>
  from course in facts.OfType<Course>()
  where course.school == school
  select course
);

var catalog = await j.Query(lps, coursesInSchool);
catalog
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 101 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 101</td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 102 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 102</td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 201 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 201</td></tr></tbody></table></div></details></td></tr><tr><td>3</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 301 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 301</td></tr></tbody></table></div></details></td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# ## Existential Conditions
#
# So far this model lets the school offer a course, but it doesn't let the school stop offering a course.
# Facts are immutable, which means that they can't be modified or deleted.
# We need a way of simulating deletion.
#
# We'll do that with a new fact.
# The school will create a `Course.Deleted` fact to stop offering a course.
# Then we'll modify the specification to exclude courses that have been deleted.

# %%
[FactType("Course.Deleted")]
public record CourseDeleted(Course course, DateTime deletedAt) {}

Renderer.RenderTypes(typeof(CourseDeleted))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.49.3 (20211023.0002)
#  -->
# <!-- Pages: 1 -->
# <svg width="142pt" height="218pt"
#  viewBox="0.00 0.00 141.89 218.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 214)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-214 137.89,-214 137.89,4 -4,4"/>
# <!-- Course.Deleted -->
# <g id="node1" class="node">
# <title>Course.Deleted</title>
# <ellipse fill="none" stroke="black" cx="66.94" cy="-18" rx="66.89" ry="18"/>
# <text text-anchor="middle" x="66.94" y="-14.3" font-family="Times New Roman,serif" font-size="14.00">Course.Deleted</text>
# </g>
# <!-- Course -->
# <g id="node2" class="node">
# <title>Course</title>
# <ellipse fill="none" stroke="black" cx="66.94" cy="-105" rx="37.09" ry="18"/>
# <text text-anchor="middle" x="66.94" y="-101.3" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# </g>
# <!-- Course.Deleted&#45;&gt;Course -->
# <g id="edge1" class="edge">
# <title>Course.Deleted&#45;&gt;Course</title>
# <path fill="none" stroke="black" d="M66.94,-36.2C66.94,-47.84 66.94,-63.45 66.94,-76.76"/>
# <polygon fill="black" stroke="black" points="63.44,-76.82 66.94,-86.82 70.44,-76.82 63.44,-76.82"/>
# <text text-anchor="middle" x="85.94" y="-57.8" font-family="Times New Roman,serif" font-size="14.00">course</text>
# </g>
# <!-- School -->
# <g id="node3" class="node">
# <title>School</title>
# <ellipse fill="none" stroke="black" cx="66.94" cy="-192" rx="36.29" ry="18"/>
# <text text-anchor="middle" x="66.94" y="-188.3" font-family="Times New Roman,serif" font-size="14.00">School</text>
# </g>
# <!-- Course&#45;&gt;School -->
# <g id="edge2" class="edge">
# <title>Course&#45;&gt;School</title>
# <path fill="none" stroke="black" d="M66.94,-123.2C66.94,-134.84 66.94,-150.45 66.94,-163.76"/>
# <polygon fill="black" stroke="black" points="63.44,-163.82 66.94,-173.82 70.44,-163.82 63.44,-163.82"/>
# <text text-anchor="middle" x="85.94" y="-144.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# If the school wishes to no longer offer Trigonometry, then it would represent that with a course deletion fact.

# %%
var trigonometryDeleted = await j.Fact(new CourseDeleted(trigonometry, DateTime.Now));

Renderer.RenderFacts(algebra, geometry, trigonometryDeleted, calculus)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.49.3 (20211023.0002)
#  -->
# <!-- Pages: 1 -->
# <svg width="636pt" height="264pt"
#  viewBox="0.00 0.00 636.00 264.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 260)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-260 632,-260 632,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="236,-231 236,-252 343,-252 343,-231 236,-231"/>
# <text text-anchor="start" x="269.5" y="-237.8" font-family="Times New Roman,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="236,-210 236,-231 272,-231 272,-210 236,-210"/>
# <text text-anchor="start" x="239" y="-216.8" font-family="Times New Roman,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="272,-210 272,-231 343,-231 343,-210 272,-210"/>
# <text text-anchor="start" x="275" y="-216.8" font-family="Times New Roman,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="9,-129 9,-150 135,-150 135,-129 9,-129"/>
# <text text-anchor="start" x="51.5" y="-135.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="9,-108 9,-129 64,-129 64,-108 9,-108"/>
# <text text-anchor="start" x="12" y="-114.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="64,-108 64,-129 135,-129 135,-108 64,-108"/>
# <text text-anchor="start" x="67" y="-114.8" font-family="Times New Roman,serif" font-size="14.00">MATH 101</text>
# <polygon fill="none" stroke="black" points="8,-107 8,-151 136,-151 136,-107 8,-107"/>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M126.48,-155.11C157.22,-169.27 195.72,-187.01 227.53,-201.67"/>
# <polygon fill="black" stroke="black" points="226.2,-204.91 236.75,-205.92 229.13,-198.56 226.2,-204.91"/>
# <text text-anchor="middle" x="213" y="-176.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg== -->
# <g id="node3" class="node">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==</title>
# <polygon fill="none" stroke="black" points="171,-129 171,-150 297,-150 297,-129 171,-129"/>
# <text text-anchor="start" x="213.5" y="-135.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="171,-108 171,-129 226,-129 226,-108 171,-108"/>
# <text text-anchor="start" x="174" y="-114.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="226,-108 226,-129 297,-129 297,-108 226,-108"/>
# <text text-anchor="start" x="229" y="-114.8" font-family="Times New Roman,serif" font-size="14.00">MATH 102</text>
# <polygon fill="none" stroke="black" points="170,-107 170,-151 298,-151 298,-107 170,-107"/>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge2" class="edge">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M247.88,-155.23C254.81,-167.83 263.28,-183.24 270.73,-196.79"/>
# <polygon fill="black" stroke="black" points="267.81,-198.73 275.69,-205.81 273.94,-195.36 267.81,-198.73"/>
# <text text-anchor="middle" x="284" y="-176.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="node4" class="node">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <polygon fill="none" stroke="black" points="332,-129 332,-150 458,-150 458,-129 332,-129"/>
# <text text-anchor="start" x="374.5" y="-135.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="332,-108 332,-129 387,-129 387,-108 332,-108"/>
# <text text-anchor="start" x="335" y="-114.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="387,-108 387,-129 458,-129 458,-108 387,-108"/>
# <text text-anchor="start" x="390" y="-114.8" font-family="Times New Roman,serif" font-size="14.00">MATH 201</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge3" class="edge">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M369.34,-154.21C355.25,-167.5 337.62,-184.14 322.46,-198.43"/>
# <polygon fill="black" stroke="black" points="319.66,-196.26 314.79,-205.67 324.47,-201.35 319.66,-196.26"/>
# <text text-anchor="middle" x="368" y="-176.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- ENRgXclCMmgXPuPVvHlYM2NIFW+z3PRwDpPZvIEhsKabqIU+DlpwnnhNHk98MuEVpa5uG5mJH/dOoEk3CqwLXQ== -->
# <g id="node5" class="node">
# <title>ENRgXclCMmgXPuPVvHlYM2NIFW+z3PRwDpPZvIEhsKabqIU+DlpwnnhNHk98MuEVpa5uG5mJH/dOoEk3CqwLXQ==</title>
# <polygon fill="none" stroke="black" points="287,-26 287,-47 504,-47 504,-26 287,-26"/>
# <text text-anchor="start" x="352" y="-32.8" font-family="Times New Roman,serif" font-size="14.00">Course.Deleted</text>
# <polygon fill="none" stroke="black" points="287,-5 287,-26 347,-26 347,-5 287,-5"/>
# <text text-anchor="start" x="290" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">deletedAt</text>
# <polygon fill="none" stroke="black" points="347,-5 347,-26 504,-26 504,-5 347,-5"/>
# <text text-anchor="start" x="350" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">2023&#45;06&#45;01T13:18:03.120Z</text>
# <polygon fill="none" stroke="black" points="285.5,-4 285.5,-48 504.5,-48 504.5,-4 285.5,-4"/>
# </g>
# <!-- ENRgXclCMmgXPuPVvHlYM2NIFW+z3PRwDpPZvIEhsKabqIU+DlpwnnhNHk98MuEVpa5uG5mJH/dOoEk3CqwLXQ==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="edge4" class="edge">
# <title>ENRgXclCMmgXPuPVvHlYM2NIFW+z3PRwDpPZvIEhsKabqIU+DlpwnnhNHk98MuEVpa5uG5mJH/dOoEk3CqwLXQ==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <path fill="none" stroke="black" d="M395,-52.23C395,-64.67 395,-79.88 395,-93.4"/>
# <polygon fill="black" stroke="black" points="391.5,-93.79 395,-103.79 398.5,-93.79 391.5,-93.79"/>
# <text text-anchor="middle" x="414" y="-73.8" font-

# %% [markdown]
# We can revise the specification to return only courses that have not been deleted.

# %%
[FactType("Course.Restored")]
public record CourseRestored(CourseDeleted deleted) {}

var coursesInSchoolNotDeleted = Given<School>.Match((school, facts) =>
  facts.OfType<Course>(course =>
    course.school == school &&
    !facts.Any<CourseDeleted>(deleted =>
      deleted.course == course &&
      !facts.Any<CourseRestored>(restored =>
        restored.deleted == deleted
      )
    )
  )
);

coursesInSchoolNotDeleted.ToString()
# Out:
# (school: School) {
#     course: Course [
#         course->school: School = school
#         !E {
#             deleted: Course.Deleted [
#                 deleted->course: Course = course
#                 !E {
#                     restored: Course.Restored [
#                         restored->deleted: Course.Deleted = deleted
#                     ]
#                 }
#             ]
#         }
#     ]
# } => course

# %% [markdown]
# When we run this specification for the school "LPS Frisco", we get back the three courses that have not been deleted.

# %%
var catalogNotDeleted = await j.Query(lps, coursesInSchoolNotDeleted);

catalogNotDeleted
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 101 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 101</td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 102 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 102</td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 301 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 301</td></tr></tbody></table></div></details></td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# ### Nested Existential Conditions
#
# Mistakes happen.
# People want to undo their decisions.
# What if a school deletes a course, but then wants to restore it?
# How do you delete a deletion?
#
# We can do that by defining a new fact type called `Course.Restored`.
# A school creates this fact to restore a course that it had previously deleted.

# %%
[FactType("Course.Restored")]
public record CourseRestored(CourseDeleted deleted) {}

Renderer.RenderTypes(typeof(CourseRestored))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.49.3 (20211023.0002)
#  -->
# <!-- Pages: 1 -->
# <svg width="154pt" height="305pt"
#  viewBox="0.00 0.00 153.59 305.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 301)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-301 149.59,-301 149.59,4 -4,4"/>
# <!-- Course.Restored -->
# <g id="node1" class="node">
# <title>Course.Restored</title>
# <ellipse fill="none" stroke="black" cx="72.79" cy="-18" rx="72.59" ry="18"/>
# <text text-anchor="middle" x="72.79" y="-14.3" font-family="Times New Roman,serif" font-size="14.00">Course.Restored</text>
# </g>
# <!-- Course.Deleted -->
# <g id="node2" class="node">
# <title>Course.Deleted</title>
# <ellipse fill="none" stroke="black" cx="72.79" cy="-105" rx="66.89" ry="18"/>
# <text text-anchor="middle" x="72.79" y="-101.3" font-family="Times New Roman,serif" font-size="14.00">Course.Deleted</text>
# </g>
# <!-- Course.Restored&#45;&gt;Course.Deleted -->
# <g id="edge1" class="edge">
# <title>Course.Restored&#45;&gt;Course.Deleted</title>
# <path fill="none" stroke="black" d="M72.79,-36.2C72.79,-47.84 72.79,-63.45 72.79,-76.76"/>
# <polygon fill="black" stroke="black" points="69.29,-76.82 72.79,-86.82 76.29,-76.82 69.29,-76.82"/>
# <text text-anchor="middle" x="92.79" y="-57.8" font-family="Times New Roman,serif" font-size="14.00">deleted</text>
# </g>
# <!-- Course -->
# <g id="node3" class="node">
# <title>Course</title>
# <ellipse fill="none" stroke="black" cx="72.79" cy="-192" rx="37.09" ry="18"/>
# <text text-anchor="middle" x="72.79" y="-188.3" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# </g>
# <!-- Course.Deleted&#45;&gt;Course -->
# <g id="edge2" class="edge">
# <title>Course.Deleted&#45;&gt;Course</title>
# <path fill="none" stroke="black" d="M72.79,-123.2C72.79,-134.84 72.79,-150.45 72.79,-163.76"/>
# <polygon fill="black" stroke="black" points="69.29,-163.82 72.79,-173.82 76.29,-163.82 69.29,-163.82"/>
# <text text-anchor="middle" x="91.79" y="-144.8" font-family="Times New Roman,serif" font-size="14.00">course</text>
# </g>
# <!-- School -->
# <g id="node4" class="node">
# <title>School</title>
# <ellipse fill="none" stroke="black" cx="72.79" cy="-279" rx="36.29" ry="18"/>
# <text text-anchor="middle" x="72.79" y="-275.3" font-family="Times New Roman,serif" font-size="14.00">School</text>
# </g>
# <!-- Course&#45;&gt;School -->
# <g id="edge3" class="edge">
# <title>Course&#45;&gt;School</title>
# <path fill="none" stroke="black" d="M72.79,-210.2C72.79,-221.84 72.79,-237.45 72.79,-250.76"/>
# <polygon fill="black" stroke="black" points="69.29,-250.82 72.79,-260.82 76.29,-250.82 69.29,-250.82"/>
# <text text-anchor="middle" x="91.79" y="-231.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Now we can modify the specification to ignore deletions that have been restored.
# We do this by nesting a negative existential condition.
# In other words, the condition has a condition of its own.
#
# We look for courses that have not been deleted.
# While looking for those deletions, we consider only the ones that have not been restored.

# %%
var coursesInSchoolNotDeletedOrRestored = Given<School>.Match((school, facts) =>
  from course in facts.OfType<Course>()
  where course.school == school
  where !(
    from deleted in facts.OfType<CourseDeleted>()
    where deleted.course == course
    where !facts.Any<CourseRestored>(restored => restored.deleted == deleted)
    select deleted
  ).Any()
  select course
);

# %% [markdown]
# Let's test this out.
# Suppose that the school decides to restore Trigonometry.

# %%
var trigonometryRestored = await j.Fact(new CourseRestored(trigonometryDeleted));

Renderer.RenderFacts(algebra, geometry, trigonometryRestored, calculus)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.49.3 (20211023.0002)
#  -->
# <!-- Pages: 1 -->
# <svg width="636pt" height="349pt"
#  viewBox="0.00 0.00 636.00 349.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 345)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-345 632,-345 632,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="236,-316 236,-337 343,-337 343,-316 236,-316"/>
# <text text-anchor="start" x="269.5" y="-322.8" font-family="Times New Roman,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="236,-295 236,-316 272,-316 272,-295 236,-295"/>
# <text text-anchor="start" x="239" y="-301.8" font-family="Times New Roman,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="272,-295 272,-316 343,-316 343,-295 272,-295"/>
# <text text-anchor="start" x="275" y="-301.8" font-family="Times New Roman,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="9,-214 9,-235 135,-235 135,-214 9,-214"/>
# <text text-anchor="start" x="51.5" y="-220.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="9,-193 9,-214 64,-214 64,-193 9,-193"/>
# <text text-anchor="start" x="12" y="-199.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="64,-193 64,-214 135,-214 135,-193 64,-193"/>
# <text text-anchor="start" x="67" y="-199.8" font-family="Times New Roman,serif" font-size="14.00">MATH 101</text>
# <polygon fill="none" stroke="black" points="8,-192 8,-236 136,-236 136,-192 8,-192"/>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M126.48,-240.11C157.22,-254.27 195.72,-272.01 227.53,-286.67"/>
# <polygon fill="black" stroke="black" points="226.2,-289.91 236.75,-290.92 229.13,-283.56 226.2,-289.91"/>
# <text text-anchor="middle" x="213" y="-261.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg== -->
# <g id="node3" class="node">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==</title>
# <polygon fill="none" stroke="black" points="171,-214 171,-235 297,-235 297,-214 171,-214"/>
# <text text-anchor="start" x="213.5" y="-220.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="171,-193 171,-214 226,-214 226,-193 171,-193"/>
# <text text-anchor="start" x="174" y="-199.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="226,-193 226,-214 297,-214 297,-193 226,-193"/>
# <text text-anchor="start" x="229" y="-199.8" font-family="Times New Roman,serif" font-size="14.00">MATH 102</text>
# <polygon fill="none" stroke="black" points="170,-192 170,-236 298,-236 298,-192 170,-192"/>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge2" class="edge">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M247.88,-240.23C254.81,-252.83 263.28,-268.24 270.73,-281.79"/>
# <polygon fill="black" stroke="black" points="267.81,-283.73 275.69,-290.81 273.94,-280.36 267.81,-283.73"/>
# <text text-anchor="middle" x="284" y="-261.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="node4" class="node">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <polygon fill="none" stroke="black" points="332,-214 332,-235 458,-235 458,-214 332,-214"/>
# <text text-anchor="start" x="374.5" y="-220.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="332,-193 332,-214 387,-214 387,-193 332,-193"/>
# <text text-anchor="start" x="335" y="-199.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="387,-193 387,-214 458,-214 458,-193 387,-193"/>
# <text text-anchor="start" x="390" y="-199.8" font-family="Times New Roman,serif" font-size="14.00">MATH 201</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge3" class="edge">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M369.34,-239.21C355.25,-252.5 337.62,-269.14 322.46,-283.43"/>
# <polygon fill="black" stroke="black" points="319.66,-281.26 314.79,-290.67 324.47,-286.35 319.66,-281.26"/>
# <text text-anchor="middle" x="368" y="-261.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- ENRgXclCMmgXPuPVvHlYM2NIFW+z3PRwDpPZvIEhsKabqIU+DlpwnnhNHk98MuEVpa5uG5mJH/dOoEk3CqwLXQ== -->
# <g id="node5" class="node">
# <title>ENRgXclCMmgXPuPVvHlYM2NIFW+z3PRwDpPZvIEhsKabqIU+DlpwnnhNHk98MuEVpa5uG5mJH/dOoEk3CqwLXQ==</title>
# <polygon fill="none" stroke="black" points="287,-112 287,-133 504,-133 504,-112 287,-112"/>
# <text text-anchor="start" x="352" y="-118.8" font-family="Times New Roman,serif" font-size="14.00">Course.Deleted</text>
# <polygon fill="none" stroke="black" points="287,-91 287,-112 347,-112 347,-91 287,-91"/>
# <text text-anchor="start" x="290" y="-97.8" font-family="Times New Roman,serif" font-size="14.00">deletedAt</text>
# <polygon fill="none" stroke="black" points="347,-91 347,-112 504,-112 504,-91 347,-91"/>
# <text text-anchor="start" x="350" y="-97.8" font-family="Times New Roman,serif" font-size="14.00">2023&#45;06&#45;01T13:18:03.120Z</text>
# </g>
# <!-- ENRgXclCMmgXPuPVvHlYM2NIFW+z3PRwDpPZvIEhsKabqIU+DlpwnnhNHk98MuEVpa5uG5mJH/dOoEk3CqwLXQ==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="edge4" class="edge">
# <title>ENRgXclCMmgXPuPVvHlYM2NIFW+z3PRwDpPZvIEhsKabqIU+DlpwnnhNHk98MuEVpa5uG5mJH/dOoEk3CqwLXQ==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <path fill="none" stroke="black" d="M395,-137.21C395,-149.64 395,-165.01 395,-178.65"/>
# <polygon fill="black" stroke="black" points="391.5,-178.67 395,-188.67 398.5,-178.67 391.5,-178.67"/>
# <text text-anchor="middle" x="414" y="-158.8" font-family="Times New Roman,serif" font-size="14.00">course</text>
# </g>
# <

# %% [markdown]
# When this specification is run for the school "LPS Frisco", it returns all four courses, since trigonometry has now been restored.

# %%
var catalogNotDeletedOrRestored = await j.Query(lps, coursesInSchoolNotDeletedOrRestored);

catalogNotDeletedOrRestored
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 101 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 101</td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 102 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 102</td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 201 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 201</td></tr></tbody></table></div></details></td></tr><tr><td>3</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 301 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>name</td><td>LPS Frisco</td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td>MATH 301</td></tr></tbody></table></div></details></td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# ## Child Specifications
#
# So far we've been returning the course facts.
# But the real power of Jinaga.NET comes from being able to project those facts into types that we can use.
# Let's see how to do that.
#
# Courses have names, not just identifiers.
# Those names can change.
# So we don't want the course name to be a field of the course fact.
# Remember, facts are immutable.
#
# Instead, we'll create a new fact type called `Course.Name`.
# To change the name of a course, the school will create a new fact.

# %%
[FactType("Course.Name")]
public record CourseName(Course course, string value, CourseName[] prior) {}

Renderer.RenderTypes(typeof(CourseName), typeof(CourseRestored))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.49.3 (20211023.0002)
#  -->
# <!-- Pages: 1 -->
# <svg width="332pt" height="305pt"
#  viewBox="0.00 0.00 332.24 305.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 301)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-301 328.24,-301 328.24,4 -4,4"/>
# <!-- Course.Name -->
# <g id="node1" class="node">
# <title>Course.Name</title>
# <ellipse fill="none" stroke="black" cx="60.44" cy="-105" rx="60.39" ry="18"/>
# <text text-anchor="middle" x="60.44" y="-101.3" font-family="Times New Roman,serif" font-size="14.00">Course.Name</text>
# </g>
# <!-- Course.Name&#45;&gt;Course.Name -->
# <g id="edge2" class="edge">
# <title>Course.Name&#45;&gt;Course.Name</title>
# <path fill="none" stroke="black" d="M115.07,-97.23C128.7,-97.78 138.89,-100.37 138.89,-105 138.89,-108.4 133.39,-110.7 125.08,-111.9"/>
# <polygon fill="black" stroke="black" points="124.73,-108.42 115.07,-112.77 125.33,-115.39 124.73,-108.42"/>
# <text text-anchor="middle" x="152.89" y="-101.3" font-family="Times New Roman,serif" font-size="14.00">prior</text>
# </g>
# <!-- Course -->
# <g id="node2" class="node">
# <title>Course</title>
# <ellipse fill="none" stroke="black" cx="155.44" cy="-192" rx="37.09" ry="18"/>
# <text text-anchor="middle" x="155.44" y="-188.3" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# </g>
# <!-- Course.Name&#45;&gt;Course -->
# <g id="edge1" class="edge">
# <title>Course.Name&#45;&gt;Course</title>
# <path fill="none" stroke="black" d="M78.76,-122.39C93.59,-135.66 114.61,-154.46 130.89,-169.03"/>
# <polygon fill="black" stroke="black" points="128.67,-171.74 138.46,-175.8 133.34,-166.53 128.67,-171.74"/>
# <text text-anchor="middle" x="132.44" y="-144.8" font-family="Times New Roman,serif" font-size="14.00">course</text>
# </g>
# <!-- School -->
# <g id="node5" class="node">
# <title>School</title>
# <ellipse fill="none" stroke="black" cx="155.44" cy="-279" rx="36.29" ry="18"/>
# <text text-anchor="middle" x="155.44" y="-275.3" font-family="Times New Roman,serif" font-size="14.00">School</text>
# </g>
# <!-- Course&#45;&gt;School -->
# <g id="edge4" class="edge">
# <title>Course&#45;&gt;School</title>
# <path fill="none" stroke="black" d="M155.44,-210.2C155.44,-221.84 155.44,-237.45 155.44,-250.76"/>
# <polygon fill="black" stroke="black" points="151.94,-250.82 155.44,-260.82 158.94,-250.82 151.94,-250.82"/>
# <text text-anchor="middle" x="174.44" y="-231.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- Course.Restored -->
# <g id="node3" class="node">
# <title>Course.Restored</title>
# <ellipse fill="none" stroke="black" cx="251.44" cy="-18" rx="72.59" ry="18"/>
# <text text-anchor="middle" x="251.44" y="-14.3" font-family="Times New Roman,serif" font-size="14.00">Course.Restored</text>
# </g>
# <!-- Course.Deleted -->
# <g id="node4" class="node">
# <title>Course.Deleted</title>
# <ellipse fill="none" stroke="black" cx="251.44" cy="-105" rx="66.89" ry="18"/>
# <text text-anchor="middle" x="251.44" y="-101.3" font-family="Times New Roman,serif" font-size="14.00">Course.Deleted</text>
# </g>
# <!-- Course.Restored&#45;&gt;Course.Deleted -->
# <g id="edge3" class="edge">
# <title>Course.Restored&#45;&gt;Course.Deleted</title>
# <path fill="none" stroke="black" d="M251.44,-36.2C251.44,-47.84 251.44,-63.45 251.44,-76.76"/>
# <polygon fill="black" stroke="black" points="247.94,-76.82 251.44,-86.82 254.94,-76.82 247.94,-76.82"/>
# <text text-anchor="middle" x="271.44" y="-57.8" font-family="Times New Roman,serif" font-size="14.00">deleted</text>
# </g>
# <!-- Course.Deleted&#45;&gt;Course -->
# <g id="edge5" class="edge">
# <title>Course.Deleted&#45;&gt;Course</title>
# <path fill="none" stroke="black" d="M232.93,-122.39C217.95,-135.66 196.71,-154.46 180.25,-169.03"/>
# <polygon fill="black" stroke="black" points="177.77,-166.55 172.61,-175.8 182.41,-171.8 177.77,-166.55"/>
# <text text-anchor="middle" x="227.44" y="-144.8" font-family="Times New Roman,serif" font-size="14.00">course</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Notice how the `Course.Name` fact points back to prior `Course.Name` facts.
# This lets us modify a course name over time.
# Each version of the name points back to the version that it replaces.
#
# To get the current name of a course, we'll look for a `Course.Name` fact that has no successor.

# %%
var nameOfCourse = Given<Course>.Match((course, facts) =>
  from name in facts.OfType<CourseName>()
  where name.course == course
  where !(
    from next in facts.OfType<CourseName>()
    where next.prior.Contains(name)
    select next
  ).Any()
  select name.value
);

# %% [markdown]
# If, for example, we were to name the Algebra course, we would create a new fact.

# %%
var algebraName = await j.Fact(new CourseName(algebra, "Algebra", new CourseName[0]));

Renderer.RenderFacts(algebraName)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.49.3 (20211023.0002)
#  -->
# <!-- Pages: 1 -->
# <svg width="150pt" height="262pt"
#  viewBox="0.00 0.00 150.00 262.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 258)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-258 146,-258 146,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="18,-229 18,-250 125,-250 125,-229 18,-229"/>
# <text text-anchor="start" x="51.5" y="-235.8" font-family="Times New Roman,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="18,-208 18,-229 54,-229 54,-208 18,-208"/>
# <text text-anchor="start" x="21" y="-214.8" font-family="Times New Roman,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="54,-208 54,-229 125,-229 125,-208 54,-208"/>
# <text text-anchor="start" x="57" y="-214.8" font-family="Times New Roman,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="8,-128 8,-149 134,-149 134,-128 8,-128"/>
# <text text-anchor="start" x="50.5" y="-134.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="8,-107 8,-128 63,-128 63,-107 8,-107"/>
# <text text-anchor="start" x="11" y="-113.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="63,-107 63,-128 134,-128 134,-107 63,-107"/>
# <text text-anchor="start" x="66" y="-113.8" font-family="Times New Roman,serif" font-size="14.00">MATH 101</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M71,-153.22C71,-165.32 71,-180.19 71,-193.46"/>
# <polygon fill="black" stroke="black" points="67.5,-193.69 71,-203.69 74.5,-193.69 67.5,-193.69"/>
# <text text-anchor="middle" x="90" y="-174.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw== -->
# <g id="node3" class="node">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==</title>
# <polygon fill="none" stroke="black" points="29,-26 29,-47 114,-47 114,-26 29,-26"/>
# <text text-anchor="start" x="33" y="-32.8" font-family="Times New Roman,serif" font-size="14.00">Course.Name</text>
# <polygon fill="none" stroke="black" points="29,-5 29,-26 64,-26 64,-5 29,-5"/>
# <text text-anchor="start" x="32" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">value</text>
# <polygon fill="none" stroke="black" points="64,-5 64,-26 114,-26 114,-5 64,-5"/>
# <text text-anchor="start" x="67" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">Algebra</text>
# <polygon fill="none" stroke="black" points="27.5,-4 27.5,-48 114.5,-48 114.5,-4 27.5,-4"/>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="edge2" class="edge">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <path fill="none" stroke="black" d="M71,-52.23C71,-64.47 71,-79.35 71,-92.61"/>
# <polygon fill="black" stroke="black" points="67.5,-92.81 71,-102.81 74.5,-92.81 67.5,-92.81"/>
# <text text-anchor="middle" x="90" y="-73.8" font-family="Times New Roman,serif" font-size="14.00">course</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Then we could run the specification to get the current name of the Algebra course.

# %%
await j.Query(algebra, nameOfCourse)
# Out:
# <div class="dni-plaintext"><pre>[ Algebra ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# If we wanted to change the name to "Algebra 1", we would create a new fact.

# %%
var algebra1Name = await j.Fact(new CourseName(algebra, "Algebra 1", new [] { algebraName }));

Renderer.RenderFacts(algebra1Name)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.49.3 (20211023.0002)
#  -->
# <!-- Pages: 1 -->
# <svg width="207pt" height="363pt"
#  viewBox="0.00 0.00 206.50 363.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 359)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-359 202.5,-359 202.5,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="23,-330 23,-351 130,-351 130,-330 23,-330"/>
# <text text-anchor="start" x="56.5" y="-336.8" font-family="Times New Roman,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="23,-309 23,-330 59,-330 59,-309 23,-309"/>
# <text text-anchor="start" x="26" y="-315.8" font-family="Times New Roman,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="59,-309 59,-330 130,-330 130,-309 59,-309"/>
# <text text-anchor="start" x="62" y="-315.8" font-family="Times New Roman,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="13,-229 13,-250 139,-250 139,-229 13,-229"/>
# <text text-anchor="start" x="55.5" y="-235.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="13,-208 13,-229 68,-229 68,-208 13,-208"/>
# <text text-anchor="start" x="16" y="-214.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="68,-208 68,-229 139,-229 139,-208 68,-208"/>
# <text text-anchor="start" x="71" y="-214.8" font-family="Times New Roman,serif" font-size="14.00">MATH 101</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M76,-254.22C76,-266.32 76,-281.19 76,-294.46"/>
# <polygon fill="black" stroke="black" points="72.5,-294.69 76,-304.69 79.5,-294.69 72.5,-294.69"/>
# <text text-anchor="middle" x="95" y="-275.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw== -->
# <g id="node3" class="node">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==</title>
# <polygon fill="none" stroke="black" points="106,-128 106,-149 191,-149 191,-128 106,-128"/>
# <text text-anchor="start" x="110" y="-134.8" font-family="Times New Roman,serif" font-size="14.00">Course.Name</text>
# <polygon fill="none" stroke="black" points="106,-107 106,-128 141,-128 141,-107 106,-107"/>
# <text text-anchor="start" x="109" y="-113.8" font-family="Times New Roman,serif" font-size="14.00">value</text>
# <polygon fill="none" stroke="black" points="141,-107 141,-128 191,-128 191,-107 141,-107"/>
# <text text-anchor="start" x="144" y="-113.8" font-family="Times New Roman,serif" font-size="14.00">Algebra</text>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="edge2" class="edge">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <path fill="none" stroke="black" d="M130.39,-153.22C121.15,-165.92 109.7,-181.66 99.69,-195.42"/>
# <polygon fill="black" stroke="black" points="96.73,-193.54 93.68,-203.69 102.39,-197.66 96.73,-193.54"/>
# <text text-anchor="middle" x="135" y="-174.8" font-family="Times New Roman,serif" font-size="14.00">course</text>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA== -->
# <g id="node4" class="node">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==</title>
# <polygon fill="none" stroke="black" points="9,-26 9,-47 105,-47 105,-26 9,-26"/>
# <text text-anchor="start" x="18.5" y="-32.8" font-family="Times New Roman,serif" font-size="14.00">Course.Name</text>
# <polygon fill="none" stroke="black" points="9,-5 9,-26 44,-26 44,-5 9,-5"/>
# <text text-anchor="start" x="12" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">value</text>
# <polygon fill="none" stroke="black" points="44,-5 44,-26 105,-26 105,-5 44,-5"/>
# <text text-anchor="start" x="47" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">Algebra 1</text>
# <polygon fill="none" stroke="black" points="8,-4 8,-48 106,-48 106,-4 8,-4"/>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="edge3" class="edge">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <path fill="none" stroke="black" d="M52.73,-52.28C49.13,-77.84 45.39,-118.41 51,-153 53.24,-166.79 57.65,-181.47 62.15,-194.15"/>
# <polygon fill="black" stroke="black" points="58.98,-195.68 65.74,-203.84 65.55,-193.25 58.98,-195.68"/>
# <text text-anchor="middle" x="70" y="-124.3" font-family="Times New Roman,serif" font-size="14.00">course</text>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw== -->
# <g id="edge4" class="edge">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==</title>
# <path fill="none" stroke="black" d="M79.96,-52.23C91.87,-65.32 106.53,-81.43 119.19,-95.34"/>
# <polygon fill="black" stroke="black" points="116.67,-97.77 125.99,-102.81 121.84,-93.06 116.67,-97.77"/>
# <text text-anchor="middle" x="121" y="-73.8" font-family="Times New Roman,serif" font-size="14.00">prior</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# That changes the name that is returned by the specification.

# %%
await j.Query(algebra, nameOfCourse)
# Out:
# <div class="dni-plaintext"><pre>[ Algebra 1 ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# Let's set the names of all of the courses.

# %%
var geometryName = await j.Fact(new CourseName(geometry, "Geometry", new CourseName[0]));
var trigonometryName = await j.Fact(new CourseName(trigonometry, "Trigonometry", new CourseName[0]));
var calculusName = await j.Fact(new CourseName(calculus, "Calculus", new CourseName[0]));

Renderer.RenderFacts(algebra1Name, geometryName, trigonometryName, calculusName)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.49.3 (20211023.0002)
#  -->
# <!-- Pages: 1 -->
# <svg width="690pt" height="365pt"
#  viewBox="0.00 0.00 690.00 365.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 361)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-361 686,-361 686,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="318,-332 318,-353 425,-353 425,-332 318,-332"/>
# <text text-anchor="start" x="351.5" y="-338.8" font-family="Times New Roman,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="318,-311 318,-332 354,-332 354,-311 318,-311"/>
# <text text-anchor="start" x="321" y="-317.8" font-family="Times New Roman,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="354,-311 354,-332 425,-332 425,-311 354,-311"/>
# <text text-anchor="start" x="357" y="-317.8" font-family="Times New Roman,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="68,-231 68,-252 194,-252 194,-231 68,-231"/>
# <text text-anchor="start" x="110.5" y="-237.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="68,-210 68,-231 123,-231 123,-210 68,-210"/>
# <text text-anchor="start" x="71" y="-216.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="123,-210 123,-231 194,-231 194,-210 123,-210"/>
# <text text-anchor="start" x="126" y="-216.8" font-family="Times New Roman,serif" font-size="14.00">MATH 101</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M189.4,-256.09C223.79,-270.28 267.44,-288.28 303.33,-303.09"/>
# <polygon fill="black" stroke="black" points="302.17,-306.39 312.75,-306.97 304.84,-299.92 302.17,-306.39"/>
# <text text-anchor="middle" x="285" y="-277.8" font-family="Times New Roman,serif" font-size="14.00">school</text>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw== -->
# <g id="node3" class="node">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==</title>
# <polygon fill="none" stroke="black" points="106,-129 106,-150 191,-150 191,-129 106,-129"/>
# <text text-anchor="start" x="110" y="-135.8" font-family="Times New Roman,serif" font-size="14.00">Course.Name</text>
# <polygon fill="none" stroke="black" points="106,-108 106,-129 141,-129 141,-108 106,-108"/>
# <text text-anchor="start" x="109" y="-114.8" font-family="Times New Roman,serif" font-size="14.00">value</text>
# <polygon fill="none" stroke="black" points="141,-108 141,-129 191,-129 191,-108 141,-108"/>
# <text text-anchor="start" x="144" y="-114.8" font-family="Times New Roman,serif" font-size="14.00">Algebra</text>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="edge2" class="edge">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <path fill="none" stroke="black" d="M143.88,-154.21C141.77,-166.64 139.16,-182.01 136.84,-195.65"/>
# <polygon fill="black" stroke="black" points="133.36,-195.22 135.14,-205.67 140.26,-196.4 133.36,-195.22"/>
# <text text-anchor="middle" x="160" y="-176.8" font-family="Times New Roman,serif" font-size="14.00">course</text>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA== -->
# <g id="node4" class="node">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==</title>
# <polygon fill="none" stroke="black" points="9,-26 9,-47 105,-47 105,-26 9,-26"/>
# <text text-anchor="start" x="18.5" y="-32.8" font-family="Times New Roman,serif" font-size="14.00">Course.Name</text>
# <polygon fill="none" stroke="black" points="9,-5 9,-26 44,-26 44,-5 9,-5"/>
# <text text-anchor="start" x="12" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">value</text>
# <polygon fill="none" stroke="black" points="44,-5 44,-26 105,-26 105,-5 44,-5"/>
# <text text-anchor="start" x="47" y="-11.8" font-family="Times New Roman,serif" font-size="14.00">Algebra 1</text>
# <polygon fill="none" stroke="black" points="8,-4 8,-48 106,-48 106,-4 8,-4"/>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="edge3" class="edge">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <path fill="none" stroke="black" d="M49.15,-52.24C42.29,-78.96 35.48,-121.76 50,-155 57.57,-172.34 71.35,-187.46 85.42,-199.49"/>
# <polygon fill="black" stroke="black" points="83.27,-202.25 93.23,-205.85 87.69,-196.82 83.27,-202.25"/>
# <text text-anchor="middle" x="69" y="-125.3" font-family="Times New Roman,serif" font-size="14.00">course</text>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw== -->
# <g id="edge4" class="edge">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==</title>
# <path fill="none" stroke="black" d="M79.73,-52.23C91.72,-65.54 106.56,-82 119.33,-96.18"/>
# <polygon fill="black" stroke="black" points="116.89,-98.7 126.19,-103.79 122.09,-94.02 116.89,-98.7"/>
# <text text-anchor="middle" x="122" y="-73.8" font-family="Times New Roman,serif" font-size="14.00">prior</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg== -->
# <g id="node5" class="node">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==</title>
# <polygon fill="none" stroke="black" points="228,-231 228,-252 354,-252 354,-231 228,-231"/>
# <text text-anchor="start" x="270.5" y="-237.8" font-family="Times New Roman,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="228,-210 228,-231 283,-231 283,-210 228,-210"/>
# <text text-anchor="start" x="231" y="-216.8" font-family="Times New Roman,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="283,-210 283,-231 354,-231 354,-210 283,-210"/>
# <text text-anchor="start" x="286" y="-216.8" font-family="Times New Roman,serif" font-size="14.00">MATH 102</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4Eg

# %% [markdown]
# We want the names of all courses in the catalog.
# Let's add the name to the projection.

# %%
var coursesInSchoolWithNames = Given<School>.Match((school, facts) =>
  from course in facts.OfType<Course>()
  where course.school == school
  select new {
    identifier = course.identifier,
    names =
      from name in facts.OfType<CourseName>()
      where name.course == course
      where !(
        from next in facts.OfType<CourseName>()
        where next.prior.Contains(name)
        select next
      ).Any()
      select name.value
  }
);

var catalogWithNames = await j.Query(lps, coursesInSchoolWithNames);

catalogWithNames
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ identifier = MATH 101, names = System.Linq.Enumerable+<OfTypeIterator>d__65`1[System.String] }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>identifier</td><td>MATH 101</td></tr><tr><td>names</td><td><div class="dni-plaintext"><pre>[ Algebra 1 ]</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ identifier = MATH 102, names = System.Linq.Enumerable+<OfTypeIterator>d__65`1[System.String] }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>identifier</td><td>MATH 102</td></tr><tr><td>names</td><td><div class="dni-plaintext"><pre>[ Geometry ]</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ identifier = MATH 201, names = System.Linq.Enumerable+<OfTypeIterator>d__65`1[System.String] }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>identifier</td><td>MATH 201</td></tr><tr><td>names</td><td><div class="dni-plaintext"><pre>[ Trigonometry ]</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>3</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ identifier = MATH 301, names = System.Linq.Enumerable+<OfTypeIterator>d__65`1[System.String] }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>identifier</td><td>MATH 301</td></tr><tr><td>names</td><td><div class="dni-plaintext"><pre>[ Calculus ]</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# Now we can bind that projection to the user interface and see the course names.

# %% [markdown]
# ## Conclusion
#
# Jinaga.NET captures immutable facts whenever the user makes a decision.
# Then it uses specifications to project those facts into types that we can see on the user interface.
#
# Thinking in terms of immutable historical facts is a little different.
# But I think you will find that once you master it, you will be able to build some amazing things.
#
# Build something awesome!
