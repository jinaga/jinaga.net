# %%
#r "nuget: Jinaga"
#r "nuget: Jinaga.UnitTest"
#r "nuget: Jinaga.Graphviz"
using Jinaga;
using Jinaga.UnitTest;
using Jinaga.Graphviz;

var j = JinagaClient.Create();
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga, 0.9.7</span></li><li><span>Jinaga.Graphviz, 0.9.7</span></li><li><span>Jinaga.UnitTest, 0.9.7</span></li></ul></div></div>

# %% [markdown]
# # School Example
#
# Jinaga.NET is a data management library for .NET.
# It captures facts that represent decisions that a user has made.
# Then it uses specifications to turn those facts into projections that appear on the user interface.
#
# Let's start with a model of a school offering courses.
# Both the school and the course are types of facts.

# %%
[FactType("School")]
public record School(string name) {}

[FactType("Course")]
public record Course(School school, string identifier) {}

Renderer.RenderTypes(typeof(School), typeof(Course))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (20230911.1827)
#  -->
# <!-- Pages: 1 -->
# <svg width="82pt" height="133pt"
#  viewBox="0.00 0.00 82.04 132.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 128.5)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-128.5 78.04,-128.5 78.04,4 -4,4"/>
# <!-- Course -->
# <g id="node1" class="node">
# <title>Course</title>
# <ellipse fill="none" stroke="black" cx="37.02" cy="-18" rx="37.02" ry="18"/>
# <text text-anchor="middle" x="37.02" y="-12.95" font-family="Times,serif" font-size="14.00">Course</text>
# </g>
# <!-- School -->
# <g id="node2" class="node">
# <title>School</title>
# <ellipse fill="none" stroke="black" cx="37.02" cy="-106.5" rx="36.51" ry="18"/>
# <text text-anchor="middle" x="37.02" y="-101.45" font-family="Times,serif" font-size="14.00">School</text>
# </g>
# <!-- Course&#45;&gt;School -->
# <g id="edge1" class="edge">
# <title>Course&#45;&gt;School</title>
# <path fill="none" stroke="black" d="M37.02,-36.09C37.02,-47.74 37.02,-63.45 37.02,-76.98"/>
# <polygon fill="black" stroke="black" points="33.52,-76.64 37.02,-86.64 40.52,-76.64 33.52,-76.64"/>
# <text text-anchor="middle" x="54.65" y="-57.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Suppose that the model contained the following facts.

# %%
var lps = await j.Fact(new School("LPS Frisco"));
var algebra = await j.Fact(new Course(lps, "MATH 101"));
var geometry = await j.Fact(new Course(lps, "MATH 102"));
var trigonometry = await j.Fact(new Course(lps, "MATH 201"));
var calculus = await j.Fact(new Course(lps, "MATH 301"));

Renderer.RenderFacts(algebra, geometry, trigonometry, calculus)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (20230911.1827)
#  -->
# <!-- Pages: 1 -->
# <svg width="630pt" height="167pt"
#  viewBox="0.00 0.00 630.00 166.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 162.5)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-162.5 626,-162.5 626,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="260,-132.5 260,-154.5 362,-154.5 362,-132.5 260,-132.5"/>
# <text text-anchor="start" x="292.25" y="-138.2" font-family="Times,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="260,-110.5 260,-132.5 296,-132.5 296,-110.5 260,-110.5"/>
# <text text-anchor="start" x="263" y="-116.2" font-family="Times,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="296,-110.5 296,-132.5 362,-132.5 362,-110.5 296,-110.5"/>
# <text text-anchor="start" x="298.62" y="-116.2" font-family="Times,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="9,-27 9,-49 133,-49 133,-27 9,-27"/>
# <text text-anchor="start" x="51.88" y="-32.7" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="9,-5 9,-27 64,-27 64,-5 9,-5"/>
# <text text-anchor="start" x="11.75" y="-10.7" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="64,-5 64,-27 133,-27 133,-5 64,-5"/>
# <text text-anchor="start" x="67" y="-10.7" font-family="Times,serif" font-size="14.00">MATH 101</text>
# <polygon fill="none" stroke="black" points="8,-4 8,-50 134,-50 134,-4 8,-4"/>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M131.25,-53.98C165.25,-68.64 207.83,-87.01 243.02,-102.18"/>
# <polygon fill="black" stroke="black" points="241.25,-105.23 251.82,-105.98 244.02,-98.8 241.25,-105.23"/>
# <text text-anchor="middle" x="223.62" y="-75.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg== -->
# <g id="node3" class="node">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==</title>
# <polygon fill="none" stroke="black" points="169,-27 169,-49 293,-49 293,-27 169,-27"/>
# <text text-anchor="start" x="211.88" y="-32.7" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="169,-5 169,-27 224,-27 224,-5 169,-5"/>
# <text text-anchor="start" x="171.75" y="-10.7" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="224,-5 224,-27 293,-27 293,-5 224,-5"/>
# <text text-anchor="start" x="227" y="-10.7" font-family="Times,serif" font-size="14.00">MATH 102</text>
# <polygon fill="none" stroke="black" points="168,-4 168,-50 294,-50 294,-4 168,-4"/>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge2" class="edge">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M250.98,-53.85C261.23,-67.11 273.84,-83.43 284.86,-97.68"/>
# <polygon fill="black" stroke="black" points="282.01,-99.72 290.9,-105.49 287.55,-95.44 282.01,-99.72"/>
# <text text-anchor="middle" x="293.62" y="-75.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="node4" class="node">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <polygon fill="none" stroke="black" points="329,-27 329,-49 453,-49 453,-27 329,-27"/>
# <text text-anchor="start" x="371.88" y="-32.7" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="329,-5 329,-27 384,-27 384,-5 329,-5"/>
# <text text-anchor="start" x="331.75" y="-10.7" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="384,-5 384,-27 453,-27 453,-5 384,-5"/>
# <text text-anchor="start" x="387" y="-10.7" font-family="Times,serif" font-size="14.00">MATH 201</text>
# <polygon fill="none" stroke="black" points="328,-4 328,-50 454,-50 454,-4 328,-4"/>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge3" class="edge">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M371.02,-53.85C360.77,-67.11 348.16,-83.43 337.14,-97.68"/>
# <polygon fill="black" stroke="black" points="334.45,-95.44 331.1,-105.49 339.99,-99.72 334.45,-95.44"/>
# <text text-anchor="middle" x="373.62" y="-75.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ== -->
# <g id="node5" class="node">
# <title>kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ==</title>
# <polygon fill="none" stroke="black" points="489,-27 489,-49 613,-49 613,-27 489,-27"/>
# <text text-anchor="start" x="531.88" y="-32.7" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="489,-5 489,-27 544,-27 544,-5 489,-5"/>
# <text text-anchor="start" x="491.75" y="-10.7" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="544,-5 544,-27 613,-27 613,-5 544,-5"/>
# <text text-anchor="start" x="547" y="-10.7" font-family="Times,serif" font-size="14.00">MATH 301</text>
# <polygon fill="none" stroke="black" points="488,-4 488,-50 614,-50 614,-4 488,-4"/>
# </g>
# <!-- kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge4" class="edge">
# <title>kx9coOGM5rOjFI9dxNAsrNU1l9oQzEjeszW43KlFqoGxKZ3+G7oqTZAVZjhzXMB+oL6RTF0TDBRQjRhAqg7WlQ==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M490.75,-53.98C456.75,-68.64 414.17,-87.01 378.98,-102.18"/>
# <polygon fill="black" stroke="black" points="377.98,-98.8 370.18,-105.98 380.75,-105.23 377.98,-98.8"/>
# <text text-anchor="middle" x="462.62" y="-75.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# This forms a graph.
# Each fact points up to its predecessor.
# The school was founded before it offered courses.
# The courses, however, are not related to each other.
#
# Given these facts, we can write a specification to return the catalog of courses offered by the school.

# %%
var coursesInSchool = Given<School>.Match((school, facts) =>
  from course in facts.OfType<Course>()
  where course.school == school
  select course
);

var catalog = await j.Query(coursesInSchool, lps);
catalog
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 101 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Graph</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Jinaga.Facts.FactGraph</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>FactReferences</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School: Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>School</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course: 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>Course</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Last</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course: 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>Course</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Graph</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Jinaga.Facts.FactGraph</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>FactReferences</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School: Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td>School</td></tr><tr><td>Hash</td><td>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Last</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School: Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>School</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>name</td><td><div class="dni-plaintext"><pre>LPS Frisco</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td><div class="dni-plainte ...

# %% [markdown]
# ## Existential Conditions
#
# So far this model lets the school offer a course, but it doesn't let the school stop offering a course.
# Facts are immutable, which means that they can't be modified or deleted.
# We need a way of simulating deletion.
#
# We'll do that with a new fact.
# The school will create a `Course.Deleted` fact to stop offering a course.
# Then we'll modify the specification to exclude courses that have been deleted.

# %%
[FactType("Course.Deleted")]
public record CourseDeleted(Course course, DateTime deletedAt) {}

Renderer.RenderTypes(typeof(CourseDeleted))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (20230911.1827)
#  -->
# <!-- Pages: 1 -->
# <svg width="144pt" height="221pt"
#  viewBox="0.00 0.00 144.48 221.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 217)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-217 140.48,-217 140.48,4 -4,4"/>
# <!-- Course.Deleted -->
# <g id="node1" class="node">
# <title>Course.Deleted</title>
# <ellipse fill="none" stroke="black" cx="68.24" cy="-18" rx="68.24" ry="18"/>
# <text text-anchor="middle" x="68.24" y="-12.95" font-family="Times,serif" font-size="14.00">Course.Deleted</text>
# </g>
# <!-- Course -->
# <g id="node2" class="node">
# <title>Course</title>
# <ellipse fill="none" stroke="black" cx="68.24" cy="-106.5" rx="37.02" ry="18"/>
# <text text-anchor="middle" x="68.24" y="-101.45" font-family="Times,serif" font-size="14.00">Course</text>
# </g>
# <!-- Course.Deleted&#45;&gt;Course -->
# <g id="edge1" class="edge">
# <title>Course.Deleted&#45;&gt;Course</title>
# <path fill="none" stroke="black" d="M68.24,-36.09C68.24,-47.74 68.24,-63.45 68.24,-76.98"/>
# <polygon fill="black" stroke="black" points="64.74,-76.64 68.24,-86.64 71.74,-76.64 64.74,-76.64"/>
# <text text-anchor="middle" x="85.87" y="-57.2" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- School -->
# <g id="node3" class="node">
# <title>School</title>
# <ellipse fill="none" stroke="black" cx="68.24" cy="-195" rx="36.51" ry="18"/>
# <text text-anchor="middle" x="68.24" y="-189.95" font-family="Times,serif" font-size="14.00">School</text>
# </g>
# <!-- Course&#45;&gt;School -->
# <g id="edge2" class="edge">
# <title>Course&#45;&gt;School</title>
# <path fill="none" stroke="black" d="M68.24,-124.59C68.24,-136.24 68.24,-151.95 68.24,-165.48"/>
# <polygon fill="black" stroke="black" points="64.74,-165.14 68.24,-175.14 71.74,-165.14 64.74,-165.14"/>
# <text text-anchor="middle" x="85.87" y="-145.7" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# If the school wishes to no longer offer Trigonometry, then it would represent that with a course deletion fact.

# %%
var trigonometryDeleted = await j.Fact(new CourseDeleted(trigonometry, DateTime.Now));

Renderer.RenderFacts(algebra, geometry, trigonometryDeleted, calculus)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (20230911.1827)
#  -->
# <!-- Pages: 1 -->
# <svg width="628pt" height="273pt"
#  viewBox="0.00 0.00 628.00 273.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 269)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-269 624,-269 624,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="234,-239 234,-261 336,-261 336,-239 234,-239"/>
# <text text-anchor="start" x="266.25" y="-244.7" font-family="Times,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="234,-217 234,-239 270,-239 270,-217 234,-217"/>
# <text text-anchor="start" x="237" y="-222.7" font-family="Times,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="270,-217 270,-239 336,-239 336,-217 270,-217"/>
# <text text-anchor="start" x="272.62" y="-222.7" font-family="Times,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="9,-133.5 9,-155.5 133,-155.5 133,-133.5 9,-133.5"/>
# <text text-anchor="start" x="51.88" y="-139.2" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="9,-111.5 9,-133.5 64,-133.5 64,-111.5 9,-111.5"/>
# <text text-anchor="start" x="11.75" y="-117.2" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="64,-111.5 64,-133.5 133,-133.5 133,-111.5 64,-111.5"/>
# <text text-anchor="start" x="67" y="-117.2" font-family="Times,serif" font-size="14.00">MATH 101</text>
# <polygon fill="none" stroke="black" points="8,-110.5 8,-156.5 134,-156.5 134,-110.5 8,-110.5"/>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M124.73,-160.48C154.65,-174.96 192.03,-193.04 223.17,-208.1"/>
# <polygon fill="black" stroke="black" points="221.58,-211.21 232.11,-212.42 224.63,-204.91 221.58,-211.21"/>
# <text text-anchor="middle" x="208.62" y="-181.7" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg== -->
# <g id="node3" class="node">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==</title>
# <polygon fill="none" stroke="black" points="169,-133.5 169,-155.5 293,-155.5 293,-133.5 169,-133.5"/>
# <text text-anchor="start" x="211.88" y="-139.2" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="169,-111.5 169,-133.5 224,-133.5 224,-111.5 169,-111.5"/>
# <text text-anchor="start" x="171.75" y="-117.2" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="224,-111.5 224,-133.5 293,-133.5 293,-111.5 224,-111.5"/>
# <text text-anchor="start" x="227" y="-117.2" font-family="Times,serif" font-size="14.00">MATH 102</text>
# <polygon fill="none" stroke="black" points="168,-110.5 168,-156.5 294,-156.5 294,-110.5 168,-110.5"/>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge2" class="edge">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M244.49,-160.35C251.27,-173.36 259.6,-189.31 266.93,-203.36"/>
# <polygon fill="black" stroke="black" points="263.63,-204.6 271.36,-211.85 269.83,-201.36 263.63,-204.6"/>
# <text text-anchor="middle" x="279.62" y="-181.7" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="node4" class="node">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <polygon fill="none" stroke="black" points="328,-133.5 328,-155.5 452,-155.5 452,-133.5 328,-133.5"/>
# <text text-anchor="start" x="370.88" y="-139.2" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="328,-111.5 328,-133.5 383,-133.5 383,-111.5 328,-111.5"/>
# <text text-anchor="start" x="330.75" y="-117.2" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="383,-111.5 383,-133.5 452,-133.5 452,-111.5 383,-111.5"/>
# <text text-anchor="start" x="386" y="-117.2" font-family="Times,serif" font-size="14.00">MATH 201</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge3" class="edge">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M364.85,-159.29C350.93,-173.02 333.44,-190.25 318.39,-205.09"/>
# <polygon fill="black" stroke="black" points="316.05,-202.48 311.39,-211.99 320.97,-207.46 316.05,-202.48"/>
# <text text-anchor="middle" x="361.62" y="-181.7" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- We72057qC7iKJFhdxHBTzkQP2/rCt928qVEc1MYxpfGqrO9cpTvYlSlf5McZR8evctHy6Ng4SGpbBfycWZPHNA== -->
# <g id="node5" class="node">
# <title>We72057qC7iKJFhdxHBTzkQP2/rCt928qVEc1MYxpfGqrO9cpTvYlSlf5McZR8evctHy6Ng4SGpbBfycWZPHNA==</title>
# <polygon fill="none" stroke="black" points="282.5,-27 282.5,-49 497.5,-49 497.5,-27 282.5,-27"/>
# <text text-anchor="start" x="348" y="-32.7" font-family="Times,serif" font-size="14.00">Course.Deleted</text>
# <polygon fill="none" stroke="black" points="282.5,-5 282.5,-27 340.5,-27 340.5,-5 282.5,-5"/>
# <text text-anchor="start" x="285.25" y="-10.7" font-family="Times,serif" font-size="14.00">deletedAt</text>
# <polygon fill="none" stroke="black" points="340.5,-5 340.5,-27 497.5,-27 497.5,-5 340.5,-5"/>
# <text text-anchor="start" x="343.25" y="-10.7" font-family="Times,serif" font-size="14.00">2024&#45;02&#45;11T04:53:47.013Z</text>
# <polygon fill="none" stroke="black" points="281.5,-4 281.5,-50 498.5,-50 498.5,-4 281.5,-4"/>
# </g>
# <!-- We72057qC7iKJFhdxHBTzkQP2/rCt928qVEc1MYxpfGqrO9cpTvYlSlf5McZR8evctHy6Ng4SGpbBfycWZPHNA==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="edge4" class="edge">
# <title>We72057qC7iKJFhdxHBTzkQP2/rCt928qVEc1MYxpfGqrO9cpTvYlSlf5McZR8evctHy6Ng4SGpbBfycWZPHNA==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <path fill="none" stroke="black" d="M390,-53.83C390,-66.68 390,-82.41 390,-96.42"/>
# <polygon fill="black" stroke="black" points="386.5,-96.17 390,-106.17 393.5,-96.17 386.5,-96.17"/>
# <text text-anchor="middle" x="407.62" y="-75.2" font-family="Times,

# %% [markdown]
# We can revise the specification to return only courses that have not been deleted.

# %%
[FactType("Course.Restored")]
public record CourseRestored(CourseDeleted deleted) {}

var coursesInSchoolNotDeleted = Given<School>.Match((school, facts) =>
  facts.OfType<Course>(course =>
    course.school == school &&
    !facts.Any<CourseDeleted>(deleted =>
      deleted.course == course &&
      !facts.Any<CourseRestored>(restored =>
        restored.deleted == deleted
      )
    )
  )
);

coursesInSchoolNotDeleted.ToString()
# Out:
# (school: School) {
#     course: Course [
#         course->school: School = school
#         !E {
#             deleted: Course.Deleted [
#                 deleted->course: Course = course
#                 !E {
#                     restored: Course.Restored [
#                         restored->deleted: Course.Deleted = deleted
#                     ]
#                 }
#             ]
#         }
#     ]
# } => course

# %% [markdown]
# When we run this specification for the school "LPS Frisco", we get back the three courses that have not been deleted.

# %%
var catalogNotDeleted = await j.Query(coursesInSchoolNotDeleted, lps);

catalogNotDeleted
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 101 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Graph</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Jinaga.Facts.FactGraph</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>FactReferences</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School: Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>School</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course: 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>Course</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Last</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course: 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>Course</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Graph</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Jinaga.Facts.FactGraph</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>FactReferences</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School: Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td>School</td></tr><tr><td>Hash</td><td>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Last</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School: Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>School</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>name</td><td><div class="dni-plaintext"><pre>LPS Frisco</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td><div class="dni-plainte ...

# %% [markdown]
# ### Nested Existential Conditions
#
# Mistakes happen.
# People want to undo their decisions.
# What if a school deletes a course, but then wants to restore it?
# How do you delete a deletion?
#
# We can do that by defining a new fact type called `Course.Restored`.
# A school creates this fact to restore a course that it had previously deleted.

# %%
[FactType("Course.Restored")]
public record CourseRestored(CourseDeleted deleted) {}

Renderer.RenderTypes(typeof(CourseRestored))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (20230911.1827)
#  -->
# <!-- Pages: 1 -->
# <svg width="153pt" height="310pt"
#  viewBox="0.00 0.00 152.67 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 148.67,-305.5 148.67,4 -4,4"/>
# <!-- Course.Restored -->
# <g id="node1" class="node">
# <title>Course.Restored</title>
# <ellipse fill="none" stroke="black" cx="72.34" cy="-18" rx="72.34" ry="18"/>
# <text text-anchor="middle" x="72.34" y="-12.95" font-family="Times,serif" font-size="14.00">Course.Restored</text>
# </g>
# <!-- Course.Deleted -->
# <g id="node2" class="node">
# <title>Course.Deleted</title>
# <ellipse fill="none" stroke="black" cx="72.34" cy="-106.5" rx="68.24" ry="18"/>
# <text text-anchor="middle" x="72.34" y="-101.45" font-family="Times,serif" font-size="14.00">Course.Deleted</text>
# </g>
# <!-- Course.Restored&#45;&gt;Course.Deleted -->
# <g id="edge1" class="edge">
# <title>Course.Restored&#45;&gt;Course.Deleted</title>
# <path fill="none" stroke="black" d="M72.34,-36.09C72.34,-47.74 72.34,-63.45 72.34,-76.98"/>
# <polygon fill="black" stroke="black" points="68.84,-76.64 72.34,-86.64 75.84,-76.64 68.84,-76.64"/>
# <text text-anchor="middle" x="91.84" y="-57.2" font-family="Times,serif" font-size="14.00">deleted</text>
# </g>
# <!-- Course -->
# <g id="node3" class="node">
# <title>Course</title>
# <ellipse fill="none" stroke="black" cx="72.34" cy="-195" rx="37.02" ry="18"/>
# <text text-anchor="middle" x="72.34" y="-189.95" font-family="Times,serif" font-size="14.00">Course</text>
# </g>
# <!-- Course.Deleted&#45;&gt;Course -->
# <g id="edge2" class="edge">
# <title>Course.Deleted&#45;&gt;Course</title>
# <path fill="none" stroke="black" d="M72.34,-124.59C72.34,-136.24 72.34,-151.95 72.34,-165.48"/>
# <polygon fill="black" stroke="black" points="68.84,-165.14 72.34,-175.14 75.84,-165.14 68.84,-165.14"/>
# <text text-anchor="middle" x="89.96" y="-145.7" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- School -->
# <g id="node4" class="node">
# <title>School</title>
# <ellipse fill="none" stroke="black" cx="72.34" cy="-283.5" rx="36.51" ry="18"/>
# <text text-anchor="middle" x="72.34" y="-278.45" font-family="Times,serif" font-size="14.00">School</text>
# </g>
# <!-- Course&#45;&gt;School -->
# <g id="edge3" class="edge">
# <title>Course&#45;&gt;School</title>
# <path fill="none" stroke="black" d="M72.34,-213.09C72.34,-224.74 72.34,-240.45 72.34,-253.98"/>
# <polygon fill="black" stroke="black" points="68.84,-253.64 72.34,-263.64 75.84,-253.64 68.84,-253.64"/>
# <text text-anchor="middle" x="89.96" y="-234.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Now we can modify the specification to ignore deletions that have been restored.
# We do this by nesting a negative existential condition.
# In other words, the condition has a condition of its own.
#
# We look for courses that have not been deleted.
# While looking for those deletions, we consider only the ones that have not been restored.

# %%
var coursesInSchoolNotDeletedOrRestored = Given<School>.Match((school, facts) =>
  from course in facts.OfType<Course>()
  where course.school == school
  where !(
    from deleted in facts.OfType<CourseDeleted>()
    where deleted.course == course
    where !facts.Any<CourseRestored>(restored => restored.deleted == deleted)
    select deleted
  ).Any()
  select course
);

# %% [markdown]
# Let's test this out.
# Suppose that the school decides to restore Trigonometry.

# %%
var trigonometryRestored = await j.Fact(new CourseRestored(trigonometryDeleted));

Renderer.RenderFacts(algebra, geometry, trigonometryRestored, calculus)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (20230911.1827)
#  -->
# <!-- Pages: 1 -->
# <svg width="628pt" height="360pt"
#  viewBox="0.00 0.00 628.00 359.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 355.5)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-355.5 624,-355.5 624,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="234,-325.5 234,-347.5 336,-347.5 336,-325.5 234,-325.5"/>
# <text text-anchor="start" x="266.25" y="-331.2" font-family="Times,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="234,-303.5 234,-325.5 270,-325.5 270,-303.5 234,-303.5"/>
# <text text-anchor="start" x="237" y="-309.2" font-family="Times,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="270,-303.5 270,-325.5 336,-325.5 336,-303.5 270,-303.5"/>
# <text text-anchor="start" x="272.62" y="-309.2" font-family="Times,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="9,-220 9,-242 133,-242 133,-220 9,-220"/>
# <text text-anchor="start" x="51.88" y="-225.7" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="9,-198 9,-220 64,-220 64,-198 9,-198"/>
# <text text-anchor="start" x="11.75" y="-203.7" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="64,-198 64,-220 133,-220 133,-198 64,-198"/>
# <text text-anchor="start" x="67" y="-203.7" font-family="Times,serif" font-size="14.00">MATH 101</text>
# <polygon fill="none" stroke="black" points="8,-197 8,-243 134,-243 134,-197 8,-197"/>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M124.73,-246.98C154.65,-261.46 192.03,-279.54 223.17,-294.6"/>
# <polygon fill="black" stroke="black" points="221.58,-297.71 232.11,-298.92 224.63,-291.41 221.58,-297.71"/>
# <text text-anchor="middle" x="208.62" y="-268.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg== -->
# <g id="node3" class="node">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==</title>
# <polygon fill="none" stroke="black" points="169,-220 169,-242 293,-242 293,-220 169,-220"/>
# <text text-anchor="start" x="211.88" y="-225.7" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="169,-198 169,-220 224,-220 224,-198 169,-198"/>
# <text text-anchor="start" x="171.75" y="-203.7" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="224,-198 224,-220 293,-220 293,-198 224,-198"/>
# <text text-anchor="start" x="227" y="-203.7" font-family="Times,serif" font-size="14.00">MATH 102</text>
# <polygon fill="none" stroke="black" points="168,-197 168,-243 294,-243 294,-197 168,-197"/>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge2" class="edge">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M244.49,-246.85C251.27,-259.86 259.6,-275.81 266.93,-289.86"/>
# <polygon fill="black" stroke="black" points="263.63,-291.1 271.36,-298.35 269.83,-287.86 263.63,-291.1"/>
# <text text-anchor="middle" x="279.62" y="-268.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="node4" class="node">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <polygon fill="none" stroke="black" points="328,-220 328,-242 452,-242 452,-220 328,-220"/>
# <text text-anchor="start" x="370.88" y="-225.7" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="328,-198 328,-220 383,-220 383,-198 328,-198"/>
# <text text-anchor="start" x="330.75" y="-203.7" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="383,-198 383,-220 452,-220 452,-198 383,-198"/>
# <text text-anchor="start" x="386" y="-203.7" font-family="Times,serif" font-size="14.00">MATH 201</text>
# </g>
# <!-- T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge3" class="edge">
# <title>T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M364.85,-245.79C350.93,-259.52 333.44,-276.75 318.39,-291.59"/>
# <polygon fill="black" stroke="black" points="316.05,-288.98 311.39,-298.49 320.97,-293.96 316.05,-288.98"/>
# <text text-anchor="middle" x="361.62" y="-268.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- We72057qC7iKJFhdxHBTzkQP2/rCt928qVEc1MYxpfGqrO9cpTvYlSlf5McZR8evctHy6Ng4SGpbBfycWZPHNA== -->
# <g id="node5" class="node">
# <title>We72057qC7iKJFhdxHBTzkQP2/rCt928qVEc1MYxpfGqrO9cpTvYlSlf5McZR8evctHy6Ng4SGpbBfycWZPHNA==</title>
# <polygon fill="none" stroke="black" points="282.5,-114.5 282.5,-136.5 497.5,-136.5 497.5,-114.5 282.5,-114.5"/>
# <text text-anchor="start" x="348" y="-120.2" font-family="Times,serif" font-size="14.00">Course.Deleted</text>
# <polygon fill="none" stroke="black" points="282.5,-92.5 282.5,-114.5 340.5,-114.5 340.5,-92.5 282.5,-92.5"/>
# <text text-anchor="start" x="285.25" y="-98.2" font-family="Times,serif" font-size="14.00">deletedAt</text>
# <polygon fill="none" stroke="black" points="340.5,-92.5 340.5,-114.5 497.5,-114.5 497.5,-92.5 340.5,-92.5"/>
# <text text-anchor="start" x="343.25" y="-98.2" font-family="Times,serif" font-size="14.00">2024&#45;02&#45;11T04:53:47.013Z</text>
# </g>
# <!-- We72057qC7iKJFhdxHBTzkQP2/rCt928qVEc1MYxpfGqrO9cpTvYlSlf5McZR8evctHy6Ng4SGpbBfycWZPHNA==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw== -->
# <g id="edge4" class="edge">
# <title>We72057qC7iKJFhdxHBTzkQP2/rCt928qVEc1MYxpfGqrO9cpTvYlSlf5McZR8evctHy6Ng4SGpbBfycWZPHNA==&#45;&gt;T3Z0WTDXhGo6D3aTjxQLjR4NRzSnEZDsaP97nD2ok2GYNn7rHGD5LdzooUffO04a8DR1bCUvfc/UF4c2Y2OFkw==</title>
# <path fill="none" stroke="black" d="M390,-140.29C390,-153 390,-168.72 390,-182.76"/>
# <polygon fill="black" stroke="black" points="386.5,-182.54 390,-192.54 393.5,-182.54 386.5,-182.54"/>
# <text text-anchor="middle" x="407.62" y="-161.7" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- rZ5hqdjAH7461JgOerDo+8g/H1kZ3+OXAuK60pMWcEXPARahoGKXpBSNwEgGlbMBwlVS

# %% [markdown]
# When this specification is run for the school "LPS Frisco", it returns all four courses, since trigonometry has now been restored.

# %%
var catalogNotDeletedOrRestored = await j.Query(coursesInSchoolNotDeletedOrRestored, lps);

catalogNotDeletedOrRestored
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course { school = School { name = LPS Frisco }, identifier = MATH 101 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Graph</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Jinaga.Facts.FactGraph</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>FactReferences</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School: Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>School</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course: 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>Course</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Last</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Course: 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>Course</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>school</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School { name = LPS Frisco }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Graph</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Jinaga.Facts.FactGraph</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>FactReferences</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School: Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td>School</td></tr><tr><td>Hash</td><td>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Last</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>School: Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Type</td><td><div class="dni-plaintext"><pre>School</pre></div></td></tr><tr><td>Hash</td><td><div class="dni-plaintext"><pre>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>name</td><td><div class="dni-plaintext"><pre>LPS Frisco</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>identifier</td><td><div class="dni-plainte ...

# %% [markdown]
# ## Child Specifications
#
# So far we've been returning the course facts.
# But the real power of Jinaga.NET comes from being able to project those facts into types that we can use.
# Let's see how to do that.
#
# Courses have names, not just identifiers.
# Those names can change.
# So we don't want the course name to be a field of the course fact.
# Remember, facts are immutable.
#
# Instead, we'll create a new fact type called `Course.Name`.
# To change the name of a course, the school will create a new fact.

# %%
[FactType("Course.Name")]
public record CourseName(Course course, string value, CourseName[] prior) {}

Renderer.RenderTypes(typeof(CourseName), typeof(CourseRestored))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (20230911.1827)
#  -->
# <!-- Pages: 1 -->
# <svg width="335pt" height="310pt"
#  viewBox="0.00 0.00 335.43 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 331.43,-305.5 331.43,4 -4,4"/>
# <!-- Course.Name -->
# <g id="node1" class="node">
# <title>Course.Name</title>
# <ellipse fill="none" stroke="black" cx="62.1" cy="-106.5" rx="62.1" ry="18"/>
# <text text-anchor="middle" x="62.1" y="-101.45" font-family="Times,serif" font-size="14.00">Course.Name</text>
# </g>
# <!-- Course.Name&#45;&gt;Course.Name -->
# <g id="edge2" class="edge">
# <title>Course.Name&#45;&gt;Course.Name</title>
# <path fill="none" stroke="black" d="M118.24,-98.33C131.98,-98.94 142.2,-101.66 142.2,-106.5 142.2,-109.87 137.26,-112.21 129.63,-113.52"/>
# <polygon fill="black" stroke="black" points="129.35,-110.03 119.75,-114.52 130.05,-117 129.35,-110.03"/>
# <text text-anchor="middle" x="155.32" y="-101.45" font-family="Times,serif" font-size="14.00">prior</text>
# </g>
# <!-- Course -->
# <g id="node2" class="node">
# <title>Course</title>
# <ellipse fill="none" stroke="black" cx="158.1" cy="-195" rx="37.02" ry="18"/>
# <text text-anchor="middle" x="158.1" y="-189.95" font-family="Times,serif" font-size="14.00">Course</text>
# </g>
# <!-- Course.Name&#45;&gt;Course -->
# <g id="edge1" class="edge">
# <title>Course.Name&#45;&gt;Course</title>
# <path fill="none" stroke="black" d="M80.16,-123.77C95.05,-137.19 116.35,-156.38 132.92,-171.31"/>
# <polygon fill="black" stroke="black" points="130.19,-173.57 139.97,-177.66 134.88,-168.37 130.19,-173.57"/>
# <text text-anchor="middle" x="136.72" y="-145.7" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- School -->
# <g id="node5" class="node">
# <title>School</title>
# <ellipse fill="none" stroke="black" cx="158.1" cy="-283.5" rx="36.51" ry="18"/>
# <text text-anchor="middle" x="158.1" y="-278.45" font-family="Times,serif" font-size="14.00">School</text>
# </g>
# <!-- Course&#45;&gt;School -->
# <g id="edge4" class="edge">
# <title>Course&#45;&gt;School</title>
# <path fill="none" stroke="black" d="M158.1,-213.09C158.1,-224.74 158.1,-240.45 158.1,-253.98"/>
# <polygon fill="black" stroke="black" points="154.6,-253.64 158.1,-263.64 161.6,-253.64 154.6,-253.64"/>
# <text text-anchor="middle" x="175.72" y="-234.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- Course.Restored -->
# <g id="node3" class="node">
# <title>Course.Restored</title>
# <ellipse fill="none" stroke="black" cx="255.1" cy="-18" rx="72.34" ry="18"/>
# <text text-anchor="middle" x="255.1" y="-12.95" font-family="Times,serif" font-size="14.00">Course.Restored</text>
# </g>
# <!-- Course.Deleted -->
# <g id="node4" class="node">
# <title>Course.Deleted</title>
# <ellipse fill="none" stroke="black" cx="255.1" cy="-106.5" rx="68.24" ry="18"/>
# <text text-anchor="middle" x="255.1" y="-101.45" font-family="Times,serif" font-size="14.00">Course.Deleted</text>
# </g>
# <!-- Course.Restored&#45;&gt;Course.Deleted -->
# <g id="edge3" class="edge">
# <title>Course.Restored&#45;&gt;Course.Deleted</title>
# <path fill="none" stroke="black" d="M255.1,-36.09C255.1,-47.74 255.1,-63.45 255.1,-76.98"/>
# <polygon fill="black" stroke="black" points="251.6,-76.64 255.1,-86.64 258.6,-76.64 251.6,-76.64"/>
# <text text-anchor="middle" x="274.6" y="-57.2" font-family="Times,serif" font-size="14.00">deleted</text>
# </g>
# <!-- Course.Deleted&#45;&gt;Course -->
# <g id="edge5" class="edge">
# <title>Course.Deleted&#45;&gt;Course</title>
# <path fill="none" stroke="black" d="M236.4,-124.18C221.3,-137.64 199.92,-156.71 183.31,-171.52"/>
# <polygon fill="black" stroke="black" points="181.38,-168.55 176.25,-177.81 186.04,-173.77 181.38,-168.55"/>
# <text text-anchor="middle" x="232.72" y="-145.7" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Notice how the `Course.Name` fact points back to prior `Course.Name` facts.
# This lets us modify a course name over time.
# Each version of the name points back to the version that it replaces.
#
# To get the current name of a course, we'll look for a `Course.Name` fact that has no successor.

# %%
var nameOfCourse = Given<Course>.Match((course, facts) =>
  from name in facts.OfType<CourseName>()
  where name.course == course
  where !(
    from next in facts.OfType<CourseName>()
    where next.prior.Contains(name)
    select next
  ).Any()
  select name.value
);

# %% [markdown]
# If, for example, we were to name the Algebra course, we would create a new fact.

# %%
var algebraName = await j.Fact(new CourseName(algebra, "Algebra", new CourseName[0]));

Renderer.RenderFacts(algebraName)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (20230911.1827)
#  -->
# <!-- Pages: 1 -->
# <svg width="148pt" height="271pt"
#  viewBox="0.00 0.00 148.00 271.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 267)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-267 144,-267 144,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="19,-237 19,-259 121,-259 121,-237 19,-237"/>
# <text text-anchor="start" x="51.25" y="-242.7" font-family="Times,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="19,-215 19,-237 55,-237 55,-215 19,-215"/>
# <text text-anchor="start" x="22" y="-220.7" font-family="Times,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="55,-215 55,-237 121,-237 121,-215 55,-215"/>
# <text text-anchor="start" x="57.62" y="-220.7" font-family="Times,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="8,-132.5 8,-154.5 132,-154.5 132,-132.5 8,-132.5"/>
# <text text-anchor="start" x="50.88" y="-138.2" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="8,-110.5 8,-132.5 63,-132.5 63,-110.5 8,-110.5"/>
# <text text-anchor="start" x="10.75" y="-116.2" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="63,-110.5 63,-132.5 132,-132.5 132,-110.5 63,-110.5"/>
# <text text-anchor="start" x="66" y="-116.2" font-family="Times,serif" font-size="14.00">MATH 101</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M70,-158.31C70,-170.69 70,-185.89 70,-199.56"/>
# <polygon fill="black" stroke="black" points="66.5,-199.55 70,-209.55 73.5,-199.55 66.5,-199.55"/>
# <text text-anchor="middle" x="87.62" y="-179.7" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw== -->
# <g id="node3" class="node">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==</title>
# <polygon fill="none" stroke="black" points="28,-27 28,-49 112,-49 112,-27 28,-27"/>
# <text text-anchor="start" x="32.5" y="-32.7" font-family="Times,serif" font-size="14.00">Course.Name</text>
# <polygon fill="none" stroke="black" points="28,-5 28,-27 63,-27 63,-5 28,-5"/>
# <text text-anchor="start" x="30.88" y="-10.7" font-family="Times,serif" font-size="14.00">value</text>
# <polygon fill="none" stroke="black" points="63,-5 63,-27 112,-27 112,-5 63,-5"/>
# <text text-anchor="start" x="65.75" y="-10.7" font-family="Times,serif" font-size="14.00">Algebra</text>
# <polygon fill="none" stroke="black" points="27,-4 27,-50 113,-50 113,-4 27,-4"/>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="edge2" class="edge">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <path fill="none" stroke="black" d="M70,-53.85C70,-66.35 70,-81.58 70,-95.22"/>
# <polygon fill="black" stroke="black" points="66.5,-95.18 70,-105.18 73.5,-95.18 66.5,-95.18"/>
# <text text-anchor="middle" x="87.62" y="-75.2" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Then we could run the specification to get the current name of the Algebra course.

# %%
await j.Query(nameOfCourse, algebra)
# Out:
# <div class="dni-plaintext"><pre>[ Algebra ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# If we wanted to change the name to "Algebra 1", we would create a new fact.

# %%
var algebra1Name = await j.Fact(new CourseName(algebra, "Algebra 1", new [] { algebraName }));

Renderer.RenderFacts(algebra1Name)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (20230911.1827)
#  -->
# <!-- Pages: 1 -->
# <svg width="202pt" height="376pt"
#  viewBox="0.00 0.00 201.50 375.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 371.5)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-371.5 197.5,-371.5 197.5,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="23.5,-341.5 23.5,-363.5 125.5,-363.5 125.5,-341.5 23.5,-341.5"/>
# <text text-anchor="start" x="55.75" y="-347.2" font-family="Times,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="23.5,-319.5 23.5,-341.5 59.5,-341.5 59.5,-319.5 23.5,-319.5"/>
# <text text-anchor="start" x="26.5" y="-325.2" font-family="Times,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="59.5,-319.5 59.5,-341.5 125.5,-341.5 125.5,-319.5 59.5,-319.5"/>
# <text text-anchor="start" x="62.12" y="-325.2" font-family="Times,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="12.5,-237 12.5,-259 136.5,-259 136.5,-237 12.5,-237"/>
# <text text-anchor="start" x="55.38" y="-242.7" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="12.5,-215 12.5,-237 67.5,-237 67.5,-215 12.5,-215"/>
# <text text-anchor="start" x="15.25" y="-220.7" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="67.5,-215 67.5,-237 136.5,-237 136.5,-215 67.5,-215"/>
# <text text-anchor="start" x="70.5" y="-220.7" font-family="Times,serif" font-size="14.00">MATH 101</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M74.5,-262.81C74.5,-275.19 74.5,-290.39 74.5,-304.06"/>
# <polygon fill="black" stroke="black" points="71,-304.05 74.5,-314.05 78,-304.05 71,-304.05"/>
# <text text-anchor="middle" x="92.12" y="-284.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw== -->
# <g id="node3" class="node">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==</title>
# <polygon fill="none" stroke="black" points="101.5,-132.5 101.5,-154.5 185.5,-154.5 185.5,-132.5 101.5,-132.5"/>
# <text text-anchor="start" x="106" y="-138.2" font-family="Times,serif" font-size="14.00">Course.Name</text>
# <polygon fill="none" stroke="black" points="101.5,-110.5 101.5,-132.5 136.5,-132.5 136.5,-110.5 101.5,-110.5"/>
# <text text-anchor="start" x="104.38" y="-116.2" font-family="Times,serif" font-size="14.00">value</text>
# <polygon fill="none" stroke="black" points="136.5,-110.5 136.5,-132.5 185.5,-132.5 185.5,-110.5 136.5,-110.5"/>
# <text text-anchor="start" x="139.25" y="-116.2" font-family="Times,serif" font-size="14.00">Algebra</text>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="edge2" class="edge">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <path fill="none" stroke="black" d="M126.8,-158.31C118.05,-171.31 107.19,-187.43 97.65,-201.61"/>
# <polygon fill="black" stroke="black" points="94.81,-199.56 92.13,-209.81 100.62,-203.46 94.81,-199.56"/>
# <text text-anchor="middle" x="130.12" y="-179.7" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA== -->
# <g id="node4" class="node">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==</title>
# <polygon fill="none" stroke="black" points="9,-27 9,-49 104,-49 104,-27 9,-27"/>
# <text text-anchor="start" x="19" y="-32.7" font-family="Times,serif" font-size="14.00">Course.Name</text>
# <polygon fill="none" stroke="black" points="9,-5 9,-27 44,-27 44,-5 9,-5"/>
# <text text-anchor="start" x="11.88" y="-10.7" font-family="Times,serif" font-size="14.00">value</text>
# <polygon fill="none" stroke="black" points="44,-5 44,-27 104,-27 104,-5 44,-5"/>
# <text text-anchor="start" x="47" y="-10.7" font-family="Times,serif" font-size="14.00">Algebra 1</text>
# <polygon fill="none" stroke="black" points="8,-4 8,-50 105,-50 105,-4 8,-4"/>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="edge3" class="edge">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <path fill="none" stroke="black" d="M51.88,-53.67C47.87,-80.11 43.52,-122.42 49.25,-158.5 51.46,-172.44 55.79,-187.29 60.24,-200.22"/>
# <polygon fill="black" stroke="black" points="56.94,-201.37 63.62,-209.59 63.52,-199 56.94,-201.37"/>
# <text text-anchor="middle" x="66.12" y="-127.45" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw== -->
# <g id="edge4" class="edge">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==</title>
# <path fill="none" stroke="black" d="M78.23,-53.85C89.48,-67.24 103.36,-83.74 115.41,-98.09"/>
# <polygon fill="black" stroke="black" points="112.56,-100.13 121.67,-105.53 117.92,-95.63 112.56,-100.13"/>
# <text text-anchor="middle" x="117.62" y="-75.2" font-family="Times,serif" font-size="14.00">prior</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# That changes the name that is returned by the specification.

# %%
await j.Query(nameOfCourse, algebra)
# Out:
# <div class="dni-plaintext"><pre>[ Algebra 1 ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# Let's set the names of all of the courses.

# %%
var geometryName = await j.Fact(new CourseName(geometry, "Geometry", new CourseName[0]));
var trigonometryName = await j.Fact(new CourseName(trigonometry, "Trigonometry", new CourseName[0]));
var calculusName = await j.Fact(new CourseName(calculus, "Calculus", new CourseName[0]));

Renderer.RenderFacts(algebra1Name, geometryName, trigonometryName, calculusName)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (20230911.1827)
#  -->
# <!-- Pages: 1 -->
# <svg width="679pt" height="378pt"
#  viewBox="0.00 0.00 678.50 377.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 373.5)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-373.5 674.5,-373.5 674.5,4 -4,4"/>
# <!-- Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="node1" class="node">
# <title>Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <polygon fill="none" stroke="black" points="312.5,-343.5 312.5,-365.5 414.5,-365.5 414.5,-343.5 312.5,-343.5"/>
# <text text-anchor="start" x="344.75" y="-349.2" font-family="Times,serif" font-size="14.00">School</text>
# <polygon fill="none" stroke="black" points="312.5,-321.5 312.5,-343.5 348.5,-343.5 348.5,-321.5 312.5,-321.5"/>
# <text text-anchor="start" x="315.5" y="-327.2" font-family="Times,serif" font-size="14.00">name</text>
# <polygon fill="none" stroke="black" points="348.5,-321.5 348.5,-343.5 414.5,-343.5 414.5,-321.5 348.5,-321.5"/>
# <text text-anchor="start" x="351.12" y="-327.2" font-family="Times,serif" font-size="14.00">LPS Frisco</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="node2" class="node">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <polygon fill="none" stroke="black" points="64.5,-239 64.5,-261 188.5,-261 188.5,-239 64.5,-239"/>
# <text text-anchor="start" x="107.38" y="-244.7" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="64.5,-217 64.5,-239 119.5,-239 119.5,-217 64.5,-217"/>
# <text text-anchor="start" x="67.25" y="-222.7" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="119.5,-217 119.5,-239 188.5,-239 188.5,-217 119.5,-217"/>
# <text text-anchor="start" x="122.5" y="-222.7" font-family="Times,serif" font-size="14.00">MATH 101</text>
# </g>
# <!-- 3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw== -->
# <g id="edge1" class="edge">
# <title>3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==&#45;&gt;Y+njFMdFuJ+srMmRbiuwWP4EgODTyDqp0n2WWUPwP0celcFLjEl4VAyvHodSo0BYjb8n70Dmm+8kBfkBBvqJDw==</title>
# <path fill="none" stroke="black" d="M184.17,-264.94C217.84,-279.51 260.5,-297.96 295.77,-313.21"/>
# <polygon fill="black" stroke="black" points="294.02,-316.26 304.59,-317.02 296.8,-309.84 294.02,-316.26"/>
# <text text-anchor="middle" x="277.12" y="-286.2" font-family="Times,serif" font-size="14.00">school</text>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw== -->
# <g id="node3" class="node">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==</title>
# <polygon fill="none" stroke="black" points="101.5,-133.5 101.5,-155.5 185.5,-155.5 185.5,-133.5 101.5,-133.5"/>
# <text text-anchor="start" x="106" y="-139.2" font-family="Times,serif" font-size="14.00">Course.Name</text>
# <polygon fill="none" stroke="black" points="101.5,-111.5 101.5,-133.5 136.5,-133.5 136.5,-111.5 101.5,-111.5"/>
# <text text-anchor="start" x="104.38" y="-117.2" font-family="Times,serif" font-size="14.00">value</text>
# <polygon fill="none" stroke="black" points="136.5,-111.5 136.5,-133.5 185.5,-133.5 185.5,-111.5 136.5,-111.5"/>
# <text text-anchor="start" x="139.25" y="-117.2" font-family="Times,serif" font-size="14.00">Algebra</text>
# </g>
# <!-- pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="edge2" class="edge">
# <title>pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <path fill="none" stroke="black" d="M139.43,-159.29C137.34,-172 134.76,-187.72 132.45,-201.76"/>
# <polygon fill="black" stroke="black" points="129.01,-201.12 130.84,-211.56 135.92,-202.26 129.01,-201.12"/>
# <text text-anchor="middle" x="154.12" y="-181.7" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA== -->
# <g id="node4" class="node">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==</title>
# <polygon fill="none" stroke="black" points="9,-27 9,-49 104,-49 104,-27 9,-27"/>
# <text text-anchor="start" x="19" y="-32.7" font-family="Times,serif" font-size="14.00">Course.Name</text>
# <polygon fill="none" stroke="black" points="9,-5 9,-27 44,-27 44,-5 9,-5"/>
# <text text-anchor="start" x="11.88" y="-10.7" font-family="Times,serif" font-size="14.00">value</text>
# <polygon fill="none" stroke="black" points="44,-5 44,-27 104,-27 104,-5 44,-5"/>
# <text text-anchor="start" x="47" y="-10.7" font-family="Times,serif" font-size="14.00">Algebra 1</text>
# <polygon fill="none" stroke="black" points="8,-4 8,-50 105,-50 105,-4 8,-4"/>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg== -->
# <g id="edge3" class="edge">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;3nDvbOUcWyAgS5+kFM0LSdDaHyJ6+/kSpTnpWspJA3NB22qfOIkhc/KSBs8QYwLhd9j7+AbhVnMhWMIfGeDbFg==</title>
# <path fill="none" stroke="black" d="M48.71,-53.76C41.81,-81.3 34.86,-125.69 49.25,-160.5 56.4,-177.8 69.49,-193.27 82.89,-205.75"/>
# <polygon fill="black" stroke="black" points="80.28,-208.11 90.09,-212.12 84.92,-202.87 80.28,-208.11"/>
# <text text-anchor="middle" x="67.12" y="-128.45" font-family="Times,serif" font-size="14.00">course</text>
# </g>
# <!-- yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw== -->
# <g id="edge4" class="edge">
# <title>yygvw5ZpzbSmA7Cdsxt2pGeCjr5D+IJ1gGcsRr11b6NTiZRwxPOqQ2fHtmgZsYEdh9luvDudqHw98fludjfyZA==&#45;&gt;pUqklGMiDc6YL0cfflosFfbt5HmL0PZFDF4ubEOxwYoESxw3dd/3G55nNKPodIZY+1TgLLzbbUHeDpPDQ8pIxw==</title>
# <path fill="none" stroke="black" d="M78.01,-53.83C89.34,-67.45 103.38,-84.31 115.55,-98.92"/>
# <polygon fill="black" stroke="black" points="112.78,-101.08 121.87,-106.52 118.16,-96.6 112.78,-101.08"/>
# <text text-anchor="middle" x="118.62" y="-75.2" font-family="Times,serif" font-size="14.00">prior</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg== -->
# <g id="node5" class="node">
# <title>i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg==</title>
# <polygon fill="none" stroke="black" points="222.5,-239 222.5,-261 346.5,-261 346.5,-239 222.5,-239"/>
# <text text-anchor="start" x="265.38" y="-244.7" font-family="Times,serif" font-size="14.00">Course</text>
# <polygon fill="none" stroke="black" points="222.5,-217 222.5,-239 277.5,-239 277.5,-217 222.5,-217"/>
# <text text-anchor="start" x="225.25" y="-222.7" font-family="Times,serif" font-size="14.00">identifier</text>
# <polygon fill="none" stroke="black" points="277.5,-217 277.5,-239 346.5,-239 346.5,-217 277.5,-217"/>
# <text text-anchor="start" x="280.5" y="-222.7" font-family="Times,serif" font-size="14.00">MATH 102</text>
# </g>
# <!-- i4bD0lcETEhyNl7+agqmySwaWJ/iR41ao2Li5wdBlebaQoJTksNdKijPFwb8uJNxSJXWRP/c7b5HjcVdikdQtg=

# %% [markdown]
# We want the names of all courses in the catalog.
# Let's add the name to the projection.

# %%
var coursesInSchoolWithNames = Given<School>.Match((school, facts) =>
  from course in facts.OfType<Course>()
  where course.school == school
  select new {
    identifier = course.identifier,
    names =
      from name in facts.OfType<CourseName>()
      where name.course == course
      where !(
        from next in facts.OfType<CourseName>()
        where next.prior.Contains(name)
        select next
      ).Any()
      select name.value
  }
);

var catalogWithNames = await j.Query(coursesInSchoolWithNames, lps);

catalogWithNames
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ identifier = MATH 101, names = System.Linq.Enumerable+&lt;OfTypeIterator&gt;d__66`1[System.String] }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>identifier</td><td><div class="dni-plaintext"><pre>MATH 101</pre></div></td></tr><tr><td>names</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ Algebra 1 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td><i>(values)</i></td><td><div class="dni-plaintext"><pre>[ Algebra 1 ]</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ identifier = MATH 102, names = System.Linq.Enumerable+&lt;OfTypeIterator&gt;d__66`1[System.String] }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>identifier</td><td><div class="dni-plaintext"><pre>MATH 102</pre></div></td></tr><tr><td>names</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ Geometry ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td><i>(values)</i></td><td><div class="dni-plaintext"><pre>[ Geometry ]</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ identifier = MATH 201, names = System.Linq.Enumerable+&lt;OfTypeIterator&gt;d__66`1[System.String] }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>identifier</td><td><div class="dni-plaintext"><pre>MATH 201</pre></div></td></tr><tr><td>names</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ Trigonometry ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td><i>(values)</i></td><td><div class="dni-plaintext"><pre>[ Trigonometry ]</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>3</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ identifier = MATH 301, names = System.Linq.Enumerable+&lt;OfTypeIterator&gt;d__66`1[System.String] }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>identifier</td><td><div class="dni-plaintext"><pre>MATH 301</pre></div></td></tr><tr><td>names</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ Calculus ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td><i>(values)</i></td><td><div class="dni-plaintext"><pre>[ Calculus ]</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# Now we can bind that projection to the user interface and see the course names.

# %% [markdown]
# ## Conclusion
#
# Jinaga.NET captures immutable facts whenever the user makes a decision.
# Then it uses specifications to project those facts into types that we can see on the user interface.
#
# Thinking in terms of immutable historical facts is a little different.
# But I think you will find that once you master it, you will be able to build some amazing things.
#
# Build something awesome!
