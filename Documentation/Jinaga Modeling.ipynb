// %% [markdown]
// C# records only live in memory in a single process. If we want to take that idea of immutable records beyond the .NET runtime, we'll need some help. That's what Jinaga does.
//
// We can store immutable records -- what Jinaga calls _facts_ -- in a local database. And we can share them with other computers. And we get the same semantics: two facts with the same type and fields are actually the same fact.

// %%
#r "../Jinaga.Graphviz/bin/Debug/net5.0/Jinaga.UnitTest.dll"
using Jinaga;

[FactType("Jinaga.User")]
record User(string publicKey);

string publicKey = "--- PUBLIC KEY ---";
new User(publicKey)
// Out:
// <table><thead><tr><th>publicKey</th></tr></thead><tbody><tr><td><div class="dni-plaintext">--- PUBLIC KEY ---</div></td></tr></tbody></table>

// %%
using Jinaga.UnitTest;

var j = JinagaTest.Create();

var firstUser = await j.Fact(new User(publicKey));
var secondUser = await j.Fact(new User(publicKey));

firstUser.Equals(secondUser)
// Out:
// <div class="dni-plaintext">True</div>

// %%
#r "../Jinaga.Graphviz/bin/Debug/net5.0/Jinaga.Graphviz.dll"
using Jinaga.Graphviz;

[FactType("Corporate.Company")]
record Company(string identifier);

[FactType("Corporate.Employee")]
record Employee(Company company, int employeeNumber);

var contoso = await j.Fact(new Company("Contoso"));
var jane = await j.Fact(new Employee(contoso, 1));
var bob = await j.Fact(new Employee(contoso, 2));

var employees = await j.Query(contoso, Given<Company>.Match((company, facts) =>
    facts.OfType<Employee>().Where(employee => employee.company == company)
));
Renderer.RenderFacts(employees)
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 2.47.0 (20210316.0004)
//  -->
// <!-- Pages: 1 -->
// <svg width="302pt" height="161pt"
//  viewBox="0.00 0.00 302.00 161.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 157)">
// <polygon fill="white" stroke="transparent" points="-4,4 -4,-157 298,-157 298,4 -4,4"/>
// <!-- Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA== -->
// <g id="node1" class="node">
// <title>Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA==</title>
// <polygon fill="none" stroke="black" points="88,-128 88,-149 207,-149 207,-128 88,-128"/>
// <text text-anchor="start" x="91.5" y="-134.8" font-family="Times,serif" font-size="14.00">Corporate.Company</text>
// <polygon fill="none" stroke="black" points="88,-107 88,-128 143,-128 143,-107 88,-107"/>
// <text text-anchor="start" x="91" y="-113.8" font-family="Times,serif" font-size="14.00">identifier</text>
// <polygon fill="none" stroke="black" points="143,-107 143,-128 207,-128 207,-107 143,-107"/>
// <text text-anchor="start" x="146" y="-113.8" font-family="Times,serif" font-size="14.00">&quot;Contoso&quot;</text>
// </g>
// <!-- e8GRnNs82hya4TBWe6DZ+XeMmBpE4WLwKpQ/WWt3kLw9XJ/f8Fur3rxZGnanLWnNBLkTIhEal3dYdDcMSxtkWw== -->
// <g id="node2" class="node">
// <title>e8GRnNs82hya4TBWe6DZ+XeMmBpE4WLwKpQ/WWt3kLw9XJ/f8Fur3rxZGnanLWnNBLkTIhEal3dYdDcMSxtkWw==</title>
// <polygon fill="none" stroke="black" points="9,-26 9,-47 129,-47 129,-26 9,-26"/>
// <text text-anchor="start" x="12" y="-32.8" font-family="Times,serif" font-size="14.00">Corporate.Employee</text>
// <polygon fill="none" stroke="black" points="9,-5 9,-26 115,-26 115,-5 9,-5"/>
// <text text-anchor="start" x="12.5" y="-11.8" font-family="Times,serif" font-size="14.00">employeeNumber</text>
// <polygon fill="none" stroke="black" points="115,-5 115,-26 129,-26 129,-5 115,-5"/>
// <text text-anchor="start" x="118.5" y="-11.8" font-family="Times,serif" font-size="14.00">1</text>
// <polygon fill="none" stroke="black" points="8,-4 8,-48 130,-48 130,-4 8,-4"/>
// </g>
// <!-- e8GRnNs82hya4TBWe6DZ+XeMmBpE4WLwKpQ/WWt3kLw9XJ/f8Fur3rxZGnanLWnNBLkTIhEal3dYdDcMSxtkWw==&#45;&gt;Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA== -->
// <g id="edge1" class="edge">
// <title>e8GRnNs82hya4TBWe6DZ+XeMmBpE4WLwKpQ/WWt3kLw9XJ/f8Fur3rxZGnanLWnNBLkTIhEal3dYdDcMSxtkWw==&#45;&gt;Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA==</title>
// <path fill="none" stroke="black" d="M88.68,-52.23C98.7,-65.08 110.99,-80.83 121.7,-94.56"/>
// <polygon fill="black" stroke="black" points="119.22,-97.08 128.13,-102.81 124.74,-92.77 119.22,-97.08"/>
// <text text-anchor="middle" x="138.5" y="-73.8" font-family="Times,serif" font-size="14.00">company</text>
// </g>
// <!-- XCHL++Wd2RaM0c5N1ea02JHVuElx5qoVkCbQS8iXiXrXvqxK7jyBwK0cQwyaJXzrbkoX24SO0vtRdjoW5a3Ljg== -->
// <g id="node3" class="node">
// <title>XCHL++Wd2RaM0c5N1ea02JHVuElx5qoVkCbQS8iXiXrXvqxK7jyBwK0cQwyaJXzrbkoX24SO0vtRdjoW5a3Ljg==</title>
// <polygon fill="none" stroke="black" points="165,-26 165,-47 285,-47 285,-26 165,-26"/>
// <text text-anchor="start" x="168" y="-32.8" font-family="Times,serif" font-size="14.00">Corporate.Employee</text>
// <polygon fill="none" stroke="black" points="165,-5 165,-26 271,-26 271,-5 165,-5"/>
// <text text-anchor="start" x="168.5" y="-11.8" font-family="Times,serif" font-size="14.00">employeeNumber</text>
// <polygon fill="none" stroke="black" points="271,-5 271,-26 285,-26 285,-5 271,-5"/>
// <text text-anchor="start" x="274.5" y="-11.8" font-family="Times,serif" font-size="14.00">2</text>
// <polygon fill="none" stroke="black" points="164,-4 164,-48 286,-48 286,-4 164,-4"/>
// </g>
// <!-- XCHL++Wd2RaM0c5N1ea02JHVuElx5qoVkCbQS8iXiXrXvqxK7jyBwK0cQwyaJXzrbkoX24SO0vtRdjoW5a3Ljg==&#45;&gt;Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA== -->
// <g id="edge2" class="edge">
// <title>XCHL++Wd2RaM0c5N1ea02JHVuElx5qoVkCbQS8iXiXrXvqxK7jyBwK0cQwyaJXzrbkoX24SO0vtRdjoW5a3Ljg==&#45;&gt;Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA==</title>
// <path fill="none" stroke="black" d="M205.32,-52.23C195.3,-65.08 183.01,-80.83 172.3,-94.56"/>
// <polygon fill="black" stroke="black" points="169.26,-92.77 165.87,-102.81 174.78,-97.08 169.26,-92.77"/>
// <text text-anchor="middle" x="215.5" y="-73.8" font-family="Times,serif" font-size="14.00">company</text>
// </g>
// </g>
// </svg>

// %%
[FactType("Corporate.Employee.Name")]
record EmployeeName(Employee employee, string name, EmployeeName[] prior);

var initialJane = await j.Fact(new EmployeeName(jane, "Jane", new EmployeeName[0]));
var initialBob = await j.Fact(new EmployeeName(bob, "Bob", new EmployeeName[0]));
var secondBobMispeld = await j.Fact(new EmployeeName(bob, "Rober", new [] { initialBob }));
var secondBob = await j.Fact(new EmployeeName(bob, "Robert", new [] { initialBob }));
var correctedBob = await j.Fact(new EmployeeName(bob, "Robert", new [] {
    secondBobMispeld, secondBob
}));

var namesOfEmployees = Given<Company>.Match((company, facts) =>
    from employeeName in facts.OfType<EmployeeName>()
    where employeeName.employee.company == company
    where !(
        from next in facts.OfType<EmployeeName>()
        where next.prior.Contains(employeeName)
        select next
    ).Any()
    select employeeName
);
var names = await j.Query(contoso, namesOfEmployees);
Renderer.RenderFacts(names)
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 2.47.0 (20210316.0004)
//  -->
// <!-- Pages: 1 -->
// <svg width="567pt" height="365pt"
//  viewBox="0.00 0.00 567.00 365.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 361)">
// <polygon fill="white" stroke="transparent" points="-4,4 -4,-361 563,-361 563,4 -4,4"/>
// <!-- Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA== -->
// <g id="node1" class="node">
// <title>Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA==</title>
// <polygon fill="none" stroke="black" points="122.5,-332 122.5,-353 241.5,-353 241.5,-332 122.5,-332"/>
// <text text-anchor="start" x="126" y="-338.8" font-family="Times,serif" font-size="14.00">Corporate.Company</text>
// <polygon fill="none" stroke="black" points="122.5,-311 122.5,-332 177.5,-332 177.5,-311 122.5,-311"/>
// <text text-anchor="start" x="125.5" y="-317.8" font-family="Times,serif" font-size="14.00">identifier</text>
// <polygon fill="none" stroke="black" points="177.5,-311 177.5,-332 241.5,-332 241.5,-311 177.5,-311"/>
// <text text-anchor="start" x="180.5" y="-317.8" font-family="Times,serif" font-size="14.00">&quot;Contoso&quot;</text>
// </g>
// <!-- e8GRnNs82hya4TBWe6DZ+XeMmBpE4WLwKpQ/WWt3kLw9XJ/f8Fur3rxZGnanLWnNBLkTIhEal3dYdDcMSxtkWw== -->
// <g id="node2" class="node">
// <title>e8GRnNs82hya4TBWe6DZ+XeMmBpE4WLwKpQ/WWt3kLw9XJ/f8Fur3rxZGnanLWnNBLkTIhEal3dYdDcMSxtkWw==</title>
// <polygon fill="none" stroke="black" points="44.5,-231 44.5,-252 164.5,-252 164.5,-231 44.5,-231"/>
// <text text-anchor="start" x="47.5" y="-237.8" font-family="Times,serif" font-size="14.00">Corporate.Employee</text>
// <polygon fill="none" stroke="black" points="44.5,-210 44.5,-231 150.5,-231 150.5,-210 44.5,-210"/>
// <text text-anchor="start" x="48" y="-216.8" font-family="Times,serif" font-size="14.00">employeeNumber</text>
// <polygon fill="none" stroke="black" points="150.5,-210 150.5,-231 164.5,-231 164.5,-210 150.5,-210"/>
// <text text-anchor="start" x="154" y="-216.8" font-family="Times,serif" font-size="14.00">1</text>
// </g>
// <!-- e8GRnNs82hya4TBWe6DZ+XeMmBpE4WLwKpQ/WWt3kLw9XJ/f8Fur3rxZGnanLWnNBLkTIhEal3dYdDcMSxtkWw==&#45;&gt;Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA== -->
// <g id="edge1" class="edge">
// <title>e8GRnNs82hya4TBWe6DZ+XeMmBpE4WLwKpQ/WWt3kLw9XJ/f8Fur3rxZGnanLWnNBLkTIhEal3dYdDcMSxtkWw==&#45;&gt;Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA==</title>
// <path fill="none" stroke="black" d="M123.34,-256.22C133.22,-268.92 145.46,-284.66 156.16,-298.42"/>
// <polygon fill="black" stroke="black" points="153.69,-300.94 162.59,-306.69 159.21,-296.65 153.69,-300.94"/>
// <text text-anchor="middle" x="174" y="-277.8" font-family="Times,serif" font-size="14.00">company</text>
// </g>
// <!-- gDcRB0YLUIOdGramOP0vafNWIAAizy4DZa9hkvTVrKiyVxXqtrjEPanndIz69eCNiazBAGK8Bpb3TP6/poPTkg== -->
// <g id="node3" class="node">
// <title>gDcRB0YLUIOdGramOP0vafNWIAAizy4DZa9hkvTVrKiyVxXqtrjEPanndIz69eCNiazBAGK8Bpb3TP6/poPTkg==</title>
// <polygon fill="none" stroke="black" points="9.5,-129 9.5,-150 166.5,-150 166.5,-129 9.5,-129"/>
// <text text-anchor="start" x="12.5" y="-135.8" font-family="Times,serif" font-size="14.00">Corporate.Employee.Name</text>
// <polygon fill="none" stroke="black" points="9.5,-108 9.5,-129 84.5,-129 84.5,-108 9.5,-108"/>
// <text text-anchor="start" x="31.5" y="-114.8" font-family="Times,serif" font-size="14.00">name</text>
// <polygon fill="none" stroke="black" points="84.5,-108 84.5,-129 166.5,-129 166.5,-108 84.5,-108"/>
// <text text-anchor="start" x="107" y="-114.8" font-family="Times,serif" font-size="14.00">&quot;Jane&quot;</text>
// <polygon fill="none" stroke="black" points="8,-107 8,-151 167,-151 167,-107 8,-107"/>
// </g>
// <!-- gDcRB0YLUIOdGramOP0vafNWIAAizy4DZa9hkvTVrKiyVxXqtrjEPanndIz69eCNiazBAGK8Bpb3TP6/poPTkg==&#45;&gt;e8GRnNs82hya4TBWe6DZ+XeMmBpE4WLwKpQ/WWt3kLw9XJ/f8Fur3rxZGnanLWnNBLkTIhEal3dYdDcMSxtkWw== -->
// <g id="edge2" class="edge">
// <title>gDcRB0YLUIOdGramOP0vafNWIAAizy4DZa9hkvTVrKiyVxXqtrjEPanndIz69eCNiazBAGK8Bpb3TP6/poPTkg==&#45;&gt;e8GRnNs82hya4TBWe6DZ+XeMmBpE4WLwKpQ/WWt3kLw9XJ/f8Fur3rxZGnanLWnNBLkTIhEal3dYdDcMSxtkWw==</title>
// <path fill="none" stroke="black" d="M91.79,-155.23C93.87,-167.47 96.4,-182.35 98.65,-195.61"/>
// <polygon fill="black" stroke="black" points="95.26,-196.54 100.39,-205.81 102.16,-195.36 95.26,-196.54"/>
// <text text-anchor="middle" x="124.5" y="-176.8" font-family="Times,serif" font-size="14.00">employee</text>
// </g>
// <!-- XCHL++Wd2RaM0c5N1ea02JHVuElx5qoVkCbQS8iXiXrXvqxK7jyBwK0cQwyaJXzrbkoX24SO0vtRdjoW5a3Ljg== -->
// <g id="node4" class="node">
// <title>XCHL++Wd2RaM0c5N1ea02JHVuElx5qoVkCbQS8iXiXrXvqxK7jyBwK0cQwyaJXzrbkoX24SO0vtRdjoW5a3Ljg==</title>
// <polygon fill="none" stroke="black" points="231.5,-231 231.5,-252 351.5,-252 351.5,-231 231.5,-231"/>
// <text text-anchor="start" x="234.5" y="-237.8" font-family="Times,serif" font-size="14.00">Corporate.Employee</text>
// <polygon fill="none" stroke="black" points="231.5,-210 231.5,-231 337.5,-231 337.5,-210 231.5,-210"/>
// <text text-anchor="start" x="235" y="-216.8" font-family="Times,serif" font-size="14.00">employeeNumber</text>
// <polygon fill="none" stroke="black" points="337.5,-210 337.5,-231 351.5,-231 351.5,-210 337.5,-210"/>
// <text text-anchor="start" x="341" y="-216.8" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- XCHL++Wd2RaM0c5N1ea02JHVuElx5qoVkCbQS8iXiXrXvqxK7jyBwK0cQwyaJXzrbkoX24SO0vtRdjoW5a3Ljg==&#45;&gt;Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA== -->
// <g id="edge3" class="edge">
// <title>XCHL++Wd2RaM0c5N1ea02JHVuElx5qoVkCbQS8iXiXrXvqxK7jyBwK0cQwyaJXzrbkoX24SO0vtRdjoW5a3Ljg==&#45;&gt;Rsx8T1+Egi1Z5EoFvQ3feM4JsojiXGdklMHSqAIaJZZdRIMlmcEQyjsOlvOBmC6Q7ZQb6a7jmy5CAndbLGtXhA==</title>
// <path fill="none" stroke="black" d="M264.59,-256.22C249.94,-269.4 231.66,-285.86 215.98,-299.97"/>
// <polygon fill="black" stroke="black" points="213.6,-297.4 208.51,-306.69 218.29,-302.6 213.6,-297.4"/>
// <text text-anchor="middle" x="269" y="-277.8" font-family="Times,serif" font-size="14.00">company</text>
// </g>
// <!-- 5dM4KUd0BajIQT20RQv9Afx+jphvsqVDA6+vQAkccPVVo2zyfSWuG5NDq1aa0o3VkhyQn/F2w2ucQSPM57BhiQ== -->
// <g id="node5" class="node">
// <title>5dM4KUd0BajIQT20RQv9Afx+jphvsqVDA6+vQAkccPVVo2zyfSWuG5NDq1aa0o3VkhyQn/F2w2ucQSPM57BhiQ==</title>
// <polygon fill="none" stroke="black" points="292.5,-129 292.5,-150 449.5,-150 449.5,-129 292.5,-129"/>
// <text text-anchor="start" x="295.5" y="-135.8" font-family="Times,serif" font-size="14.00">Corporate.Employee.Name</text>
// <polygon fill="none" stroke="black" points="292.5,-108 292.5,-129 368.5,-129 368.5,-108 292.5,-108"/>
// <text text-anchor="start" x="315" y="-114.8" font-family="Times,serif" font-size="14.00">name</text>
// <polygon fill="none" stroke="black" points="368.5,-108 368.5,-129 449.5,-129 449.5,-108 368.5,-108"/>
// <text text-anchor="start" x="391.5" y="-114.8" font-family="Times,serif" font-size="14.00">&quot;Bob&quot;</text>
// </g>
// <!-- 5dM4KUd0BajIQT20RQv9Afx+jphvsqVDA6+vQAkccPVVo2zyfSWuG5NDq1aa0o3VkhyQn/F2w2ucQSPM57BhiQ==&#45;&gt;XCHL++Wd2RaM0c5N1ea02JHVuElx5qoVkCbQS8iXiXrXvqxK7jyBwK0cQwyaJXzrbkoX24SO0vtRdjoW5a3Ljg== -->
// <g id="edge4" class="edge">
// <title>5dM4KUd0BajIQT20RQv9Afx+jphvsqVDA6+vQAkccPVVo2zyfSWuG5NDq1aa0o3VkhyQn/F2w2ucQSPM57BhiQ==&#45;&gt;XCHL++Wd2RaM0c5N1ea02JHVuElx5qoVkCbQS8iXiXrXvqxK7jyBwK0cQwyaJXzrbkoX24SO0vtRdjoW5a3Ljg==</title>
// <path fill="none" stroke="black" d="M351.38,-154.21C341.07,-167.25 328.21,-183.53 317.06,-197.65"/>
// <polygon fill="black" stroke="black" points="314.17,-195.65 310.72,-205.67 319.67,-199.99 314.17,-195.65"/>
// <text text-anchor="middle" x="362.5" y="-176.8" font-family="Times,serif" font-size="14.00">employee</text>
// </g>
// <!-- EciRc9Chx/KS8RHAQLb7MWVJRU52teUXMhuThYPbZLU7sITG8T7
